# %%
from data_load import *
# load data - > data_list
data_list = get_data("k_means_data.csv")

# %%
##vocabulary.py
from data_load import *
from vocabulary import *
word_list=get_words(data_list,1)
#new_list = delete_stop_words(word_list)
#make vocabulary list
vocab= vocabulary(word_list)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/vr/3b_f9c5j0yvgq7_41pp6_ktm0000gn/T/jieba.cache
# Loading model cost 0.791 seconds.
# Prefix dict has been built succesfully.
# The total size of our vocabulary is: 1000

# %%
## data.py
from data import *
VOCAB_SIZE = len(vocab)
EMBEDDING_SIZE= 300
#获得输入的句向量
sentence_token,input_data=get_complete_data(data_list,vocab,20,VOCAB_SIZE,EMBEDDING_SIZE)
print("input size is : {}".format(input_data.shape))
# Out:
# /Users/james/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/james/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/james/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/james/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/james/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/james/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /Users/james/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# 100%|██████████| 266/266 [00:00<00:00, 5517.87it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 40190.72it/s]
# have pretrained-vectors in vocab is: 885
# do not have pretrained-vectors in vocab is : 115
# static embeddings shape is : (1000, 300)
# input size is : (266, 300)

# %%
#获得句向量对应的index，用来输出句子的
answer_index_list=list(input_data)

# %%
# check the length of the answer list
len(answer_index_list)
# Out:
# 266

# %%
#进入聚类模型
from k_means_model import *
import matplotlib.pyplot as plt

# %%
#计算calinski_harabaz的分数，获得拐点k值
ch_score_list,ch_i_list=calculate_calinski_harabaz_score(100,165,1,input_data)
plt.figure()
plt.plot(ch_i_list,ch_score_list)
# Out:
# /Users/james/anaconda3/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (163) found smaller than n_clusters (164). Possibly due to duplicate points in X.
#   return_n_iter=True)

# %%
i_score_list,i_list=calculate_inertia_by_k(160,165,1,input_data)
plt.figure()
plt.plot(i_list,i_score_list)
# Out:
# /Users/james/anaconda3/lib/python3.6/site-packages/sklearn/cluster/k_means_.py:971: ConvergenceWarning: Number of distinct clusters (163) found smaller than n_clusters (164). Possibly due to duplicate points in X.
#   return_n_iter=True)

# %%
#k=163, 因此分为163类，获得相应的圆心和label
label,cluster=kmeans(163,input_data)

# %%
## 用来把所有的数据表按照每个簇，分到各自的簇
def make_index_map(test_label,test_list):
    map={}
    length = len(test_label)
    print(length)
    for i in range(0,length):
        key = str(test_label[i])
        print(key)
        if map.get(key) is not None:
            templist=map.get(key)
            templist.append(test_list[i])
            dicttemp={key:templist}
            map.update(dicttemp)
            
        else:
            newlist=[]
            newlist.append(test_list[i])
            newkey=str(test_label[i])
            dict={newkey:newlist}
            map.update(dict)
    return map

# %%
#进入map前，先修改数据的格式
label_list=list(label)
cluster_list =list(cluster)
default_data_list =[]
for i in answer_index_list:
    default_data_list.append(list(i))

# %%
map_contribute_data_list=make_index_map(label_list,default_data_list)
# Out:
# 266
# 84
# 94
# 66
# 108
# 95
# 77
# 161
# 98
# 140
# 5
# 151
# 97
# 90
# 118
# 60
# 33
# 62
# 6
# 100
# 134
# 59
# 40
# 128
# 102
# 139
# 152
# 61
# 56
# 156
# 106
# 10
# 21
# 109
# 143
# 116
# 31
# 117
# 155
# 92
# 26
# 79
# 135
# 8
# 115
# 57
# 105
# 93
# 76
# 69
# 2
# 64
# 39
# 0
# 50
# 78
# 121
# 36
# 63
# 14
# 13
# 32
# 29
# 15
# 41
# 18
# 25
# 86
# 11
# 52
# 70
# 119
# 48
# 1
# 20
# 47
# 96
# 58
# 44
# 46
# 83
# 85
# 113
# 65
# 28
# 147
# 137
# 42
# 17
# 133
# 73
# 23
# 37
# 30
# 35
# 51
# 123
# 53
# 67
# 80
# 19
# 7
# 82
# 145
# 146
# 72
# 34
# 120
# 112
# 22
# 129
# 16
# 159
# 126
# 127
# 136
# 99
# 154
# 158
# 45
# 12
# 162
# 75
# 122
# 110
# 130
# 27
# 3
# 157
# 142
# 91
# 124
# 138
# 9
# 68
# 87
# 49
# 38
# 43
# 24
# 118
# 60
# 33
# 62
# 6
# 100
# 160
# 59
# 40
# 114
# 102
# 139
# 144
# 61
# 56
# 131
# 106
# 10
# 21
# 109
# 54
# 116
# 31
# 117
# 150
# 92
# 26
# 81
# 135
# 8
# 115
# 57
# 105
# 93
# 76
# 69
# 2
# 104
# 39
# 0
# 50
# 78
# 121
# 36
# 63
# 14
# 13
# 32
# 29
# 15
# 41
# 18
# 25
# 86
# 11
# 52
# 103
# 119
# 48
# 1
# 20
# 47
# 96
# 101
# 44
# 4
# 149
# 85
# 113
# 65
# 28
# 111
# 137
# 42
# 17
# 133
# 132
# 23
# 37
# 30
# 35
# 51
# 71
# 53
# 67
# 80
# 19
# 7
# 74
# 145
# 146
# 72
# 34
# 120
# 148
# 22
# 55
# 16
# 89
# 126
# 127
# 136
# 99
# 154
# 153
# 12
# 125
# 162
# 12
# 122
# 107
# 130
# 27
# 3
# 88
# 142
# 91
# 124
# 138
# 9
# 68
# 87
# 49
# 38
# 43
# 24
# 141

# %%
map_contribute_data_list.keys()
# Out:
# dict_keys(['84', '94', '66', '108', '95', '77', '161', '98', '140', '5', '151', '97', '90', '118', '60', '33', '62', '6', '100', '134', '59', '40', '128', '102', '139', '152', '61', '56', '156', '106', '10', '21', '109', '143', '116', '31', '117', '155', '92', '26', '79', '135', '8', '115', '57', '105', '93', '76', '69', '2', '64', '39', '0', '50', '78', '121', '36', '63', '14', '13', '32', '29', '15', '41', '18', '25', '86', '11', '52', '70', '119', '48', '1', '20', '47', '96', '58', '44', '46', '83', '85', '113', '65', '28', '147', '137', '42', '17', '133', '73', '23', '37', '30', '35', '51', '123', '53', '67', '80', '19', '7', '82', '145', '146', '72', '34', '120', '112', '22', '129', '16', '159', '126', '127', '136', '99', '154', '158', '45', '12', '162', '75', '122', '110', '130', '27', '3', '157', '142', '91', '124', '138', '9', '68', '87', '49', '38', '43', '24', '160', '114', '144', '131', '54', '150', '81', '104', '103', '101', '4', '149', '111', '132', '71', '74', '148', '55', '89', '153', '125', '107', '88', '141'])

# %%
#形成cluster的list
cluster_list =list(cluster)

# %%
#cos 相似度算法
def get_cossimi(x,y):
    myx=np.array(x) #将列表转化为数组，更好的数学理解是向量
    myy=np.array(y) #将列表转化为数组，更好的数学理解是向量
    cos1=np.sum(myx*myy) #cos(a,b)=a*b/(|a|+|b|)
    cos21=np.sqrt(sum(myx*myx))
    cos22=np.sqrt(sum(myy*myy))
    return cos1/(float(cos21*cos22))

# %%
# 获得最接近的值，从数组中获得相关cos最大值
# 输出最接近的点

def get_max_cos(cluster,input_data):
    temp = 0
    a=0
    for i in input_data:
        if a < get_cossimi(cluster,i):
            a=get_cossimi(cluster,i)
            print(a)
            temp= i
    return temp

# %%
## 把map的value_list 进行整理，然后输出
def get_index_list(k,cluster_list):
    index=[]
    for i in range(0,k):
        key = str(i)
        templist=map_contribute_data_list.get(key)
        point=get_max_cos(cluster_list[i],np.array(templist))
        index.append(point)
    return index

# %%
#获得所有表现特征向量的句子
index=get_index_list(163,cluster_list)
# Out:
# 0.999999999999999
# 1.0000000000000004
# 0.9999999999999992
# 0.9999999999999999
# 0.9999999999999993
# 0.9999999999999994
# 0.9999999999999998
# 1.0
# 1.0
# 0.9999999999999996
# 0.9999999999999992
# 1.0000000000000007
# 0.9999999999999991
# 1.0
# 1.0000000000000002
# 0.9999999999999999
# 1.0000000000000002
# 0.9999999999999994
# 0.9999999999999999
# 1.0000000000000002
# 1.0000000000000002
# 1.0000000000000002
# 1.0000000000000002
# 1.0000000000000002
# 1.0000000000000002
# 1.0
# 1.0000000000000004
# 0.9999999999999992
# 1.0000000000000002
# 1.0000000000000007
# 1.0000000000000002
# 0.9999999999999998
# 1.0
# 0.9999999999999987
# 1.0000000000000002
# 0.9999999999999996
# 1.0000000000000002
# 1.0000000000000002
# 1.0000000000000007
# 0.9999999999999988
# 1.0000000000000004
# 1.0000000000000002
# 1.0000000000000004
# 0.9999999999999996
# 0.9999999999999996
# 1.0000000000000002
# 1.0000000000000002
# 0.9999999999999993
# 0.9999999999999993
# 1.0000000000000002
# 0.9999999999999994
# 1.0000000000000002
# 1.0000000000000002
# 1.0000000000000002
# 1.0000000000000007
# 1.0000000000000002
# 1.0
# 0.9999999999999998
# 1.0000000000000002
# 0.9999999999999991
# 1.0000000000000002
# 0.9999999999999998
# 0.9999999999999992
# 0.9999999999999998
# 0.9999999999999996
# 1.0000000000000004
# 1.0
# 1.0
# 1.0000000000000002
# 1.0000000000000007
# 0.9999999999999993
# 0.9999999999999999
# 1.0000000000000004
# 1.0000000000000002
# 1.0000000000000004
# 1.0
# 1.0000000000000002
# 1.0000000000000002
# 1.0000000000000004
# 1.0000000000000009
# 0.9999999999999997
# 1.0000000000000002
# 1.0000000000000002
# 1.0000000000000002
# 1.0000000000000016
# 0.9999999999999994
# 1.0
# 0.9999999999999999
# 1.0
# 1.0
# 1.0000000000000007
# 0.9999999999999999
# 1.0
# 1.0000000000000004
# 1.0000000000000004
# 0.9999999999999996
# 0.9999999999999999
# 0.9999999999999998
# 1.0
# 1.0000000000000007
# 1.0000000000000007
# 1.0000000000000004
# 1.0000000000000004
# 1.0000000000000002
# 0.9999999999999999
# 0.9999999999999987
# 1.0000000000000002
# 0.9999999999999994
# 1.0000000000000004
# 1.0000000000000007
# 0.9999999999999996
# 1.0000000000000004
# 1.0
# 0.9999999999999994
# 1.0000000000000004
# 0.9999999999999991
# 1.0000000000000002
# 0.9999999999999994
# 0.9999999999999993
# 0.9999999999999998
# 1.0
# 0.9999999999999998
# 0.9999999999999999
# 0.9999999999999993
# 0.9999999999999999
# 1.0
# 0.9999999999999997
# 1.0000000000000002
# 1.0000000000000009
# 1.0
# 1.0000000000000002
# 1.0000000000000002
# 1.0000000000000007
# 1.0
# 0.9999999999999996
# 0.999999999999999
# 1.0000000000000013
# 1.0
# 0.9999999999999998
# 0.9999999999999999
# 0.9999999999999998
# 0.9999999999999997
# 0.9999999999999999
# 0.999999999999999
# 1.0000000000000002
# 1.0000000000000009
# 1.0000000000000002
# 1.0
# 0.9999999999999996
# 1.0000000000000004
# 0.9999999999999991
# 0.9999999999999998
# 0.9999999999999999
# 1.0000000000000002
# 1.0000000000000004
# 1.0
# 0.9999999999999994
# 0.9999999999999997
# 1.0000000000000004
# 0.9999999999999998
# 0.9999999999999996
# 0.9999999999999998
# 1.000000000000001

# %%
#获得最后的结果，通过index
def get_answer_index(data_list,answer_index_list,sentence):
    length = len(answer_index_list)
    for i in range (0,length):
        if (sentence==answer_index_list[i]).all():
            print(i)
            return i,data_list[i]

# %%
# k = len(index) 表示输出正确，每一个array是一个点
len(index)
# Out:
# 163

# %%
answer=[]
for i in index:
    num,a = get_answer_index(data_list,answer_index_list,i)
    answer.append(a)
# Out:
# 52
# 72
# 49
# 126
# 204
# 9
# 17
# 100
# 42
# 132
# 30
# 67
# 119
# 59
# 58
# 62
# 110
# 87
# 64
# 99
# 73
# 31
# 108
# 90
# 138
# 65
# 39
# 125
# 83
# 61
# 92
# 35
# 60
# 15
# 105
# 93
# 56
# 91
# 136
# 51
# 21
# 63
# 86
# 137
# 77
# 118
# 78
# 74
# 71
# 135
# 53
# 94
# 68
# 96
# 159
# 235
# 27
# 44
# 76
# 20
# 14
# 26
# 16
# 57
# 50
# 82
# 2
# 97
# 133
# 48
# 69
# 221
# 104
# 89
# 227
# 121
# 47
# 5
# 54
# 40
# 98
# 166
# 101
# 79
# 0
# 80
# 66
# 134
# 253
# 237
# 12
# 129
# 38
# 46
# 1
# 4
# 75
# 11
# 7
# 115
# 18
# 202
# 23
# 195
# 176
# 45
# 29
# 249
# 3
# 32
# 123
# 210
# 107
# 81
# 148
# 43
# 34
# 36
# 13
# 70
# 106
# 55
# 122
# 95
# 130
# 245
# 112
# 113
# 22
# 109
# 124
# 154
# 215
# 88
# 19
# 41
# 114
# 85
# 131
# 24
# 8
# 265
# 128
# 33
# 151
# 102
# 103
# 84
# 233
# 205
# 163
# 10
# 25
# 243
# 116
# 37
# 28
# 127
# 117
# 111
# 145
# 6
# 120

# %%
# 通过最具代表性的点，输出句子
get_answer_index(data_list,answer_index_list,index[1])
# Out:
# 72
# (72, '打错字了，妈是吗')

# %%
answer
# Out:
# ['笑死，你有证据吗?血口喷人有意思吗?',
#  '打错字了，妈是吗',
#  '如果真是一手遮天也不用文哥了，皇子接班就是内战',
#  '到了这种层次，要看手工化程度了。法拉利逼格高因为年产7000辆，你得等。保时捷年产20w辆，本来就是满足更多发烧友的，玛莎也是不行，不断扩大产能，逼格都掉下来了。反正经典品牌被大厂收购的结果就是变街车。法拉利早晚也要扩大产能。。。都会变味。',
#  '那你还是先把老毛跟以前的开国皇帝比一比先吧，看看是个什么情况',
#  ' 乔丹说,他注意到许多其他人都在跟我说话了多少。',
#  '达胜',
#  '别特么吹了，不是科斯塔顶着，孔蒂上个月就下课了。车子现在缺个中场指挥官',
#  '是啊，周的势力不大的话，也不用文革这种大招了',
#  '牌子就不是一个级别的.马丁是超跑牌子就不是一个级别的.马丁是超跑',
#  '不可能的，毛大回来被毛派去做农民，蒋经国回来直接三青团书记加江西保安总队司令中将军衔，那才是培养接班人的做法尼玛，总一书二记居然是屏蔽词',
#  '相对那些整天被大炮炮击的暴露阵地，司令部是相对安全的，因为司令部要很隐蔽不能暴露啊',
#  '-- 娜家楼猪哲么克乃啊？有没有银咬啊？没引药可掐撕了啊！',
#  '的确，那些说安营不死我们就是朝鲜的明显是以自己龌龊心思揣度一个伟人，当时朝鲜战争是在什么情况下打的？几乎是集体反对，只有老毛坚持，在这种情况下老毛把自己的儿子送上战场居然也被认为是为了给儿子镀金，我也服气',
#  '共党不是老毛一个人的，任何重大的政治决定都需要政治菊投票表决。老毛还说过自己死后火葬，结果政治菊不准他火葬，死后都不准人家入土',
#  '呵呵，是送去司令部，又不是送去前线，司令部相对来说是战场上最安全的了',
#  '你要看进攻思路而不是进球，球队还需要不断磨合，等到冬季买好后卫，孔蒂便可大打攻势足球',
#  '上半场让老虎踢成啥样？有脸吹？老虎城的很多人都是客串 踢的不是自己位置 下半场跑不动了失误太多 要不你以为车子能赢',
#  '笑死，在美帝无差别轰炸下，还分前线后方？东京是前线吗？那死伤的几十万人都在前线？',
#  '只能说伊布太强，有他做支点，曼联的进攻还能凑活',
#  '那现在大陆怎么还让香港人这样选啊，明知道指定选两三个不民主',
#  '其实黄长子也是被其父算计死了，不过黄长子已经感觉到了，但君父让儿臣死，儿臣不得不死，太子为保住自己的儿子，不得已给其子改姓习（惜命之意）',
#  '等下一个天亮，把你偷拍我看海的照片送我好吗',
#  '你看球了？前60分钟打的就像业余球队，幸亏袜子神扑，对方体力不支.打强队绝对被爆',
#  '你要这么说我们可以把这个截个图去法拉利吧或者保时捷吧，911都算超跑的，你的意思是法拉利都不超跑了是吧 牛逼你自己去看看玛莎拉蒂gt再来回我',
#  '现代战场你以为还是和古代一样只要躲在后面就可以安全了？在完全没有制空权的战场后方又比前方安全多少呢，而且司令部那是敌人斩首首要目标好不，要安你这么说在司令部安全，那么安营怎么会死了呢',
#  '台湾跟老美走得近不一样，朝鲜跟苏联走得近，完全不同样的氛围',
#  '产量高是因为销量高，销量高反而在不懂的人眼中拉低了档次',
#  '说得好，当年穆里尼奥可以靠防反拿冠军，但现在想成为真强队还得靠进攻',
#  '经历过二战的人都知道：美帝是什么战斗力！当你看过东京大轰炸，当一群B29飞过大地都在颤抖！这那是镀金，明明是去送死',
#  '提醒你，曼联对老虎射门29次射门8射正，那时候老虎城士气正旺，刚2连胜',
#  '呆湾的觉悟一部分是建立在内战失败的基础上的 痛定思痛 这事放国内基本不可能的 往朝鲜发展的模式概率是极高的。',
#  '那我们也可以认为你自己以一个奴才的心态看毛，才会不相信毛是送自己儿子去镀金啊',
#  '曼联这局肯定胜利 大帅都发飙了···',
#  '早就说过某些球迷是多么的可笑，赢一场就会叛变回去，输一场就各种怀念',
#  '现在队长替补了 楼主确定曼联不会进攻？',
#  '笑死，毛远新最高职位也只是个政委，连政治菊都没进',
#  '那是后卫的问题，冬季需要买好后卫，现在切尔西的后防不稳',
#  '像兰博基尼，帕加尼，柯尼塞格，布加迪，迈凯伦这种牌子，才算真正只产超跑的',
#  '看看国峰年轻的照片和毛年轻的照片再来说吧。',
#  '然而数据就是一个助攻，不知道给什么表情好...',
#  '任何敢把自己的儿子敢把亲人送上战场的人我都敬佩如果你认为这样是奴才心态，那么我欣然接受。',
#  '那滚回车吧可好！忘了前2轮的情况了？',
#  '911应该也算超跑，最起码也是超跑入门级。',
#  '你还是先把毛岸英和蒋经国归国后的履历对比下再来说吧，还毛骨子里是家天下，儒家诛心的那一套',
#  '都想草，1我可以扒下她的吊带，2可以解衬衣扣，美滋滋',
#  '┌;呔監許χīāń灬.°',
#  '拉倒吧，一人一票的话鹿晗 吴亦凡之类保底也是肠胃。',
#  '至少还有选票，你有妈，至少还有三个人让你选，你有侯选人吗?不要告诉我你是高级黑，那我这段话就白说了',
#  '这个我知道，你说说这俩品牌那个不算吧',
#  '连这种传言都信的人，也配出来论？那个纯粹是民间无知愚昧人士根据封建那一套想象出来的但是安营如果活着，确实可能性不小',
#  '是穆里尼奥不会',
#  '那是因为毛魔鬼死后它做不了主，因为中国天亮了',
#  '一旦后防买人，切尔西进攻将更恐怖，毕竟孔蒂擅长攻势足球',
#  '去了农村，然后又去了工厂，最后派去军队。工农兵走了一遍然后你告诉我这不是在培养接班人。。。',
#  '我喜欢我飞舞的头发 ，和飘着雨还是眺望的眼光',
#  '你觉得有可能回来吗',
#  '瞎扯淡，连海棠依旧这种纯洗白片，都可以看出毛周斗法的影子',
#  '当然可能，熟读二十四史的太祖，骨子里还是家天下的。归根到底还是二皇子痴呆，大皇子无嗣，不然哪里有其他人什么事',
#  '标题说助攻，但是看了那球，真是活生生的讽刺',
#  '是啊···',
#  '啥叫故人，我还是当他是自家孩子',
#  '这场也有免费的直播？',
#  '毛魔病重时，毛远新说的话就是毛的话，还要怎么样',
#  '老毛对于自己的家属都是严格要求，不搞特殊。老毛任人唯贤，而不是任人唯亲。太宗有才，与毛政治意见相左。但老毛依旧不停启用他。老毛在世的时候，老毛的亲属就没有安插在要职上老毛死后，太宗分封诸侯，各个都赚得笑开颜毛新宇还是由于党对老毛后代的照顾，才让他有份皇粮可以领',
#  '那是后卫太烂，后卫必须要买人',
#  '  哈尔说,他的二进制码转换成语言和沟通的语言给我。',
#  '我还是资辞孔蒂常驻的，反正不会威胁到冠军',
#  '你的意思是保时捷不是超跑还是玛莎拉蒂不是超跑',
#  '真的没想过当时周毛有斗争，却一直听说当代有',
#  '反之看看老美的所谓的选举，看似多人，结果就是三个代表，到最后就强制在两个里选一个，无论其是什么样的，最可笑的是老公做完，老婆上。',
#  '曼联打赫尔城数据比你车差？至于后防坑，毕竟去年是教练差，今年是球员差',
#  '毕竟老球迷，输娜娜可以接受',
#  '6完全的压制，而曼联机会不多，直到最后才绝杀。强队还得靠进攻，这是未来的出路',
#  '要不是科斯塔连续2轮绝杀 之后又绝杀扳平 孔蒂早下课了',
#  '不管从外形 内饰 性能 品牌等各方面我都选新帕拉梅拉',
#  '毛粉？？？你毫无逻辑',
#  ' 吉米说,他给以AI的像我和他们做,因为他说的。',
#  '哦 毛远新呢',
#  '没可能，因为好多人低估了周的势力，为什么这么说呢，从后来毛自断双臂，保不住林彪，保不住高岗事件就能看出来，至于刘和彭都是单干被草的，不属于周派，对于毛打倒这两人周从来都是中立的，因为他俩在周毛斗争的棋盘上连棋子都算不上。',
#  '我抬六轮也进了12球而且',
#  '我也觉得为什么不参考台湾，同样在苏联的留学经历',
#  '厉害了我的哥，孔蒂赢一场就又吹上了。上场被阿森纳打的妈都不认识的时候在哪',
#  '孔蒂也很重视防守，防守时所有球员都得回来，但是一旦进攻敢于压上，孔蒂进攻也重视边路，但是不会盲目传中，中前场换位很灵活，同时可完全压制住对手，一次两次进攻失败不要紧，因为进攻不会停，只要防守引进好球员，切尔西进攻将很恐怖，毕竟孔蒂喜欢攻势足球',
#  ' 格雷戈里说,我到当前行不响应相对于整个会话。',
#  '被娜娜 3比0 横扫',
#  '你要是敌人，你会专挑司令部炸',
#  '超跑和跑车差别还是蛮大的。。',
#  '玛莎拉蒂这几年效益也不行，看新出的那款莱万特咋样吧，要知道当年就是靠着卡宴一举扭转了保时捷濒临破产的困境',
#  '你这话用在随便哪个教练上都挺适用',
#  '微直播 有也免费高清的额···',
#  '这个价格差别很大吧',
#  '台湾蒋氏又参考谁呢？',
#  '就你们毛粉看得出，我们还真是看不出',
#  ' 哈比卜说我学习他们的谈话,只是重复了在以后的时间。',
#  ' Malli和Raghava说他摔下屋顶,它只是向他走来。',
#  '知道什么叫做侯选人吗?别来现世了',
#  ' 凯文说,他随后问他的妈妈她为什么保持卫生巾在浴室里。',
#  ' 约翰说,他跟着一个说法得到一个朋友,我一定是朋友。',
#  '啥时候有机会出来三五瓶',
#  '24直播网有免费高清的',
#  '就贴吧这么多脑残，看来还是不要民主的好',
#  '交出签名车牌号',
#  '司令部很隐蔽？你当美帝无线电追踪是吃干饭的？',
#  '看了几个帖子，你这个姿势水平真是太低。',
#  '一身冷汗',
#  '看看林少帅选妃，你觉得呢？',
#  '新帕拉梅拉外形好看太多',
#  ' 汤姆说我提到他的指导,将显示他的房间在中国。',
#  '狗血清廷戏看多了',
#  '应该是三叉戟，保时捷产量太高了。。。',
#  '就看了一场对老虎城的球就发此感慨',
#  '车吧不是在等下一个天亮吗',
#  '0娜娜，何等威风',
#  '这个助攻 明显是打次……笑死',
#  '周就是毛的一条狗，还周派',
#  '为毛不参考呆湾',
#  '参考 呆湾就不会有温格了',
#  '不错啊，直播挺全的！',
#  '这算高级黑吗',
#  '真.破车迷',
#  '让毛远新打它脸',
#  '外形明显玛莎拉蒂',
#  '切尔西七轮进了12个球！',
#  '不是一个级别。',
#  '1用扒么？撩起来就艹了',
#  '广州…两家不同的阿迪店',
#  '老哥纽约的?',
#  '这种饼 也只有奉先能吃 不然又闷平',
#  '两个进球全是单干 稳如狗',
#  '标志好看',
#  '不大可能，鸟当主帅喜欢的是黑又硬',
#  '那你告诉我 上半场车子威胁几次',
#  '上半场赫尔城真正威胁就两次',
#  '前排，鲁迷们都起床了吧',
#  '看到温格本质',
#  '嗯嗯',
#  '拿点干货出来',
#  '贵不少',
#  'JUC-635',
#  ' 告诉我,你知道什么婆娘',
#  '超跑的入门定义好像是r8',
#  '帅！',
#  '参考现在的朝鲜',
#  '0 3',
#  '稳',
#  '后防需要买人',
#  '滚回龟吧吧',
#  '买了路易斯阿，还是孔帝不行',
#  'ご汻藖夳儖ご',
#  '改成白色恐怖么',
#  ' 流言凯文',
#  '已经是故人了',
#  '没逼两拳？不去',
#  '误变约肛贴',
#  '参考北韩',
#  '不可能',
#  'DB11可以一战',
#  '戴套咸',
#  '这哪？',
#  '有的',
#  ' 婆娘',
#  '贤妹']

# %%
type(answer)
# Out:
# list

# %%
from pandas import DataFrame

data={'sentence':answer}
df=DataFrame(data)
df.to_excel('answer.xlsx')
