# %%
import tensorflow as tf
import pandas as pd
import jieba
import os
import numpy as np
from tensorflow.contrib import layers
from collections import Counter
import tqdm
# Out:
# /Users/james/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/james/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# /Users/james/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/james/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/james/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /Users/james/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
#load data
test = pd.read_csv('./data/bert_test.txt',delimiter='\t',names=["label","review"])
val = pd.read_csv('./data/bert_val.txt',delimiter='\t',names=["label","review"])
train = pd.read_csv('./data/bert_train.txt',delimiter='\t',names=["label","review"])

#load data
#x_test = test.review
#y_test = test.label
#x_train = train.review
#y_train = train.label

# %%
x_test_pos = []
x_test_neg = []
for i in range(0,3000):
    if test.label[i] == 2:
        x_test_pos.append(test.review[i])
    if test.label[i] == 0:
        x_test_neg.append(test.review[i])

# %%
x_train_pos = []
x_train_neg = []
for i in range(0,18000):
    if train.label[i] == 2:
        x_train_pos.append(train.review[i])
    if train.label[i] == 0:
        x_train_neg.append(train.review[i])

# %%
x_train = np.concatenate((x_train_pos, x_train_pos), axis=0)

# %% [markdown]
# ### 构建字典

# %%
def get_words(txt):
    c = Counter()
    for item in txt:
        seg_list = jieba.cut(item)
        for x in seg_list:
            if len(x)>1 and x != '\r\n':
                c[x] += 1
                
        
    return c

# %%
c=get_words(x_train)

# %%
sorted(c.most_common(), key=lambda x: x[1])
# Out:
# [('4X', 2),
#  ('B5', 2),
#  ('行用', 2),
#  ('返款', 2),
#  ('玩具', 2),
#  ('到手', 2),
#  ('急性子', 2),
#  ('一小', 2),
#  ('高些', 2),
#  ('gdbai', 2),
#  ('花型', 2),
#  ('hahah', 2),
#  ('壶口', 2),
#  ('整个', 2),
#  ('亲多大', 2),
#  ('年龄', 2),
#  ('不厌其烦', 2),
#  ('兰花', 2),
#  ('手链', 2),
#  ('get', 2),
#  ('一刀', 2),
#  ('有行', 2),
#  ('庭好', 2),
#  ('发到', 2),
#  ('大方', 2),
#  ('万条', 2),
#  ('见证', 2),
#  ('澳门', 2),
#  ('永利', 2),
#  ('国际', 2),
#  ('娱乐', 2),
#  ('品牌', 2),
#  ('在线', 2),
#  ('彩种', 2),
#  ('多画面', 2),
#  ('提现', 2),
#  ('腾讯', 2),
#  ('北京', 2),
#  ('赛车', 2),
#  ('幸运', 2),
#  ('飞艇', 2),
#  ('福彩', 2),
#  ('浏览', 2),
#  ('邀请', 2),
#  ('113608', 2),
#  ('老牌子', 2),
#  ('格局', 2),
#  ('投资', 2),
#  ('风险', 2),
#  ('技术推广', 2),
#  ('工资', 2),
#  ('日结', 2),
#  ('周入', 2),
#  ('欧克', 2),
#  ('江野', 2),
#  ('新生', 2),
#  ('孩帮', 2),
#  ('牙刷', 2),
#  ('熟人', 2),
#  ('两合', 2),
#  ('瘦瘦', 2),
#  ('塑身', 2),
#  ('酵素', 2),
#  ('1600', 2),
#  ('vr', 2),
#  ('亲切', 2),
#  ('叮嘱', 2),
#  ('检验', 2),
#  ('萌宝', 2),
#  ('樱花', 2),
#  ('断带', 2),
#  ('七盒', 2),
#  ('哈祝', 2),
#  ('尝试', 2),
#  ('票据', 2),
#  ('没买成', 2),
#  ('说明书', 2),
#  ('被单', 2),
#  ('沐浴露', 2),
#  ('后来', 2),
#  ('就认', 2),
#  ('出差', 2),
#  ('让给', 2),
#  ('护手', 2),
#  ('液涂', 2),
#  ('手上', 2),
#  ('根除', 2),
#  ('小孩子', 2),
#  ('盆用', 2),
#  ('月份', 2),
#  ('带回去', 2),
#  ('皮皮虾', 2),
#  ('小伙子', 2),
#  ('睿智', 2),
#  ('连接', 2),
#  ('地址栏', 2),
#  ('游戏', 2),
#  ('一键', 2),
#  ('升满', 2),
#  ('代码', 2),
#  ('easy', 2),
#  ('安上', 2),
#  ('烤箱', 2),
#  ('食谱', 2),
#  ('香包', 2),
#  ('老人', 2),
#  ('偿金', 2),
#  ('一步', 2),
#  ('沉迷', 2),
#  ('永不', 2),
#  ('挂科', 2),
#  ('我要', 2),
#  ('一旦', 2),
#  ('布满', 2),
#  ('无限', 2),
#  ('梦想', 2),
#  ('甜蜜', 2),
#  ('好额', 2),
#  ('财神', 2),
#  ('小白脸', 2),
#  ('丝带', 2),
#  ('权重', 2),
#  ('纯手工', 2),
#  ('一机', 2),
#  ('全国', 2),
#  ('ip', 2),
#  ('包赔', 2),
#  ('咨询', 2),
#  ('试单', 2),
#  ('lV', 2),
#  ('水泡', 2),
#  ('放到', 2),
#  ('小家伙', 2),
#  ('洗衣服', 2),
#  ('伤手', 2),
#  ('花糖', 2),
#  ('送礼', 2),
#  ('比较满意', 2),
#  ('别家', 2),
#  ('人品', 2),
#  ('It', 2),
#  ('瑜伽', 2),
#  ('服女', 2),
#  ('韩版大码', 2),
#  ('运动套装', 2),
#  ('性感', 2),
#  ('不收', 2),
#  ('顺丰', 2),
#  ('可靠', 2),
#  ('刚到', 2),
#  ('已作', 2),
#  ('换购', 2),
#  ('干练', 2),
#  ('橘唇', 2),
#  ('好赞', 2),
#  ('饭钱', 2),
#  ('反馈', 2),
#  ('为啥', 2),
#  ('豆浆', 2),
#  ('浓香', 2),
#  ('喂顿', 2),
#  ('羊奶粉', 2),
#  ('申情', 2),
#  ('奖金', 2),
#  ('数量', 2),
#  ('要够', 2),
#  ('这方面', 2),
#  ('小麻烦', 2),
#  ('乖巧', 2),
#  ('好好学习', 2),
#  ('天天向上', 2),
#  ('授权书', 2),
#  ('无副作用', 2),
#  ('拿货', 2),
#  ('袋子', 2),
#  ('帮到', 2),
#  ('上周', 2),
#  ('冻顶', 2),
#  ('书籍', 2),
#  ('人类', 2),
#  ('进步', 2),
#  ('阶梯', 2),
#  ('高尔基', 2),
#  ('信得过', 2),
#  ('就是', 2),
#  ('妥善', 2),
#  ('培养', 2),
#  ('寄回', 2),
#  ('拔出来', 2),
#  ('行好', 2),
#  ('58', 2),
#  ('转好', 2),
#  ('饭后', 2),
#  ('电源插头', 2),
#  ('哈要', 2),
#  ('包活', 2),
#  ('DIY', 2),
#  ('电子书', 2),
#  ('这网', 2),
#  ('可盾', 2),
#  ('杨晓', 2),
#  ('9.9', 2),
#  ('太值', 2),
#  ('出力', 2),
#  ('搞掂', 2),
#  ('125135k', 2),
#  ('多岁', 2),
#  ('想想', 2),
#  ('三本', 2),
#  ('48', 2),
#  ('柔顺', 2),
#  ('护理', 2),
#  ('要验', 2),
#  ('货才', 2),
#  ('免得', 2),
#  ('不必要', 2),
#  ('份量', 2),
#  ('要足称', 2),
#  ('有漏', 2),
#  ('现象', 2),
#  ('十多块', 2),
#  ('药膏', 2),
#  ('pp', 2),
#  ('小熊', 2),
#  ('头枕', 2),
#  ('便于', 2),
#  ('何时', 2),
#  ('感快', 2),
#  ('811', 2),
#  ('29.9', 2),
#  ('当时', 2),
#  ('没用', 2),
#  ('福利彩票', 2),
#  ('养护', 2),
#  ('肠道', 2),
#  ('演出', 2),
#  ('除了', 2),
#  ('之外', 2),
#  ('自行车', 2),
#  ('5XL', 2),
#  ('301', 2),
#  ('进行', 2),
#  ('小心', 2),
#  ('拉丝', 2),
#  ('蝴蝶', 2),
#  ('货品', 2),
#  ('超赞', 2),
#  ('用心', 2),
#  ('邮到', 2),
#  ('渔轮', 2),
#  ('当天', 2),
#  ('超过', 2),
#  ('第二天', 2),
#  ('改错', 2),
#  ('付出', 2),
#  ('嘿嘿嘿', 2),
#  ('友谊', 2),
#  ('二天', 2),
#  ('二年级', 2),
#  ('可好', 2),
#  ('车上', 2),
#  ('送走', 2),
#  ('发质', 2),
#  ('柔软', 2),
#  ('来货', 2),
#  ('乐东县', 2),
#  ('抱由镇', 2),
#  ('二区', 2),
#  ('小玉', 2),
#  ('先充', 2),
#  ('黑三红', 2),
#  ('那箱', 2),
#  ('亏个', 2),
#  ('真实', 2),
#  ('那评', 2),
#  ('务必', 2),
#  ('京德', 2),
#  ('德粤店', 2),
#  ('随着', 2),
#  ('回升', 2),
#  ('旺季', 2),
#  ('优惠供应', 2),
#  ('下列', 2),
#  ('黑啤', 2),
#  ('亲下', 2),
#  ('亲戚', 2),
#  ('洗发水', 2),
#  ('染发', 2),
#  ('拒收', 2),
#  ('买包', 2),
#  ('好质', 2),
#  ('十追', 2),
#  ('评己', 2),
#  ('小白鞋', 2),
#  ('板鞋', 2),
#  ('白鞋', 2),
#  ('这么久', 2),
#  ('地帮', 2),
#  ('换货', 2),
#  ('多放点', 2),
#  ('冰块', 2),
#  ('地板', 2),
#  ('贴纸', 2),
#  ('客厅', 2),
#  ('背景', 2),
#  ('卧室', 2),
#  ('卫生间', 2),
#  ('装饰', 2),
#  ('浴室', 2),
#  ('自粘墙', 2),
#  ('厂价', 2),
#  ('直销', 2),
#  ('家用', 2),
#  ('全自动', 2),
#  ('超薄', 2),
#  ('吸尘器', 2),
#  ('扫地机', 2),
#  ('机器人', 2),
#  ('粗壮', 2),
#  ('树好', 2),
#  ('把握', 2),
#  ('多装', 2),
#  ('一片', 2),
#  ('黄心', 2),
#  ('睡觉', 2),
#  ('纹身', 2),
#  ('千幻', 2),
#  ('魔镜', 2),
#  ('百雀羚', 2),
#  ('防晒霜', 2),
#  ('隔离', 2),
#  ('二合一', 2),
#  ('紫外线', 2),
#  ('免邮', 2),
#  ('买纸', 2),
#  ('代收', 2),
#  ('小黄', 2),
#  ('十几块', 2),
#  ('缘分', 2),
#  ('走来', 2),
#  ('奖状', 2),
#  ('株型', 2),
#  ('能活', 2),
#  ('被套', 2),
#  ('m4', 2),
#  ('我刷', 2),
#  ('很纯', 2),
#  ('同样', 2),
#  ('用户', 2),
#  ('背面', 2),
#  ('要南', 2),
#  ('阿弥陀佛', 2),
#  ('淡斑能', 2),
#  ('上海市浦东新区', 2),
#  ('崇明县', 2),
#  ('长兴', 2),
#  ('前卫', 2),
#  ('支路', 2),
#  ('麻辣烫', 2),
#  ('拼音', 2),
#  ('豪华', 2),
#  ('高配', 2),
#  ('有配', 2),
#  ('收纳袋', 2),
#  ('随机', 2),
#  ('配送', 2),
#  ('大中小', 2),
#  ('鲨鱼', 2),
#  ('低配', 2),
#  ('线高', 2),
#  ('配版', 2),
#  ('声音', 2),
#  ('重低音', 2),
#  ('立体声', 2),
#  ('强劲', 2),
#  ('建议', 2),
#  ('买高配', 2),
#  ('中果', 2),
#  ('车友', 2),
#  ('一点点', 2),
#  ('挺大', 2),
#  ('紧致', 2),
#  ('崛起', 2),
#  ('阳刚', 2),
#  ('持久', 2),
#  ('奋斗终生', 2),
#  ('侯杰', 2),
#  ('二千', 2),
#  ('领了', 2),
#  ('乱要', 2),
#  ('17', 2),
#  ('1.2', 2),
#  ('活性炭', 2),
#  ('高效', 2),
#  ('纤维网', 2),
#  ('滤芯', 2),
#  ('有货', 2),
#  ('美的', 2),
#  ('花茶', 2),
#  ('孩在', 2),
#  ('婶婶', 2),
#  ('痛快', 2),
#  ('神奇', 2),
#  ('五毒', 2),
#  ('心疼', 2),
#  ('下火', 2),
#  ('家店', 2),
#  ('好灯', 2),
#  ('收件人', 2),
#  ('呆萌', 2),
#  ('联系电话', 2),
#  ('广西壮族自治区', 2),
#  ('百色市', 2),
#  ('右江区', 2),
#  ('体育', 2),
#  ('按照', 2),
#  ('入手', 2),
#  ('再订', 2),
#  ('二件', 2),
#  ('其中', 2),
#  ('第一件', 2),
#  ('才能', 2),
#  ('娄底', 2),
#  ('周边', 2),
#  ('路上', 2),
#  ('开业', 2),
#  ('帽檐', 2),
#  ('CD', 2),
#  ('山药', 2),
#  ('有事没事', 2),
#  ('咋样', 2),
#  ('尝后', 2),
#  ('不忘初', 2),
#  ('心爱', 2),
#  ('美好', 2),
#  ('珍贵', 2),
#  ('回买', 2),
#  ('两对', 2),
#  ('好比', 2),
#  ('小鹿', 2),
#  ('叮叮', 2),
#  ('大己', 2),
#  ('前两天', 2),
#  ('军训', 2),
#  ('越活', 2),
#  ('见效', 2),
#  ('反弹', 2),
#  ('洗澡', 2),
#  ('香香的', 2),
#  ('180', 2),
#  ('香辣', 2),
#  ('防尘', 2),
#  ('麋鹿', 2),
#  ('取来', 2),
#  ('甘哲', 2),
#  ('大枣', 2),
#  ('wq', 2),
#  ('名媛', 2),
#  ('亮收', 2),
#  ('腰显', 2),
#  ('中长款', 2),
#  ('蛋糕', 2),
#  ('新手', 2),
#  ('证书', 2),
#  ('标签', 2),
#  ('潘雅涵', 2),
#  ('学业有成', 2),
#  ('健健康康', 2),
#  ('潘立锋', 2),
#  ('彩票', 2),
#  ('中大奖', 2),
#  ('好几支', 2),
#  ('祛湿', 2),
#  ('斯滑', 2),
#  ('纸巾', 2),
#  ('亲有', 2),
#  ('我下', 2),
#  ('挺香', 2),
#  ('三瓶', 2),
#  ('五瓶', 2),
#  ('查好', 2),
#  ('五图', 2),
#  ('区安卓', 2),
#  ('窦窦', 2),
#  ('骚白', 2),
#  ('果然', 2),
#  ('名不虚传', 2),
#  ('横县', 2),
#  ('茉莉', 2),
#  ('甲天下', 2),
#  ('买买', 2),
#  ('矮牛', 2),
#  ('AD', 2),
#  ('加深', 2),
#  ('件套', 2),
#  ('来不及', 2),
#  ('三口', 2),
#  ('desc', 2),
#  ('jpg', 2),
#  ('6735707589088', 2),
#  ('mudle', 2),
#  ('chat', 2),
#  ('tag', 2),
#  ('2005', 2),
#  ('1.0', 2),
#  ('单位', 2),
#  ('云纹', 2),
#  ('草莓', 2),
#  ('秋款', 2),
#  ('划算', 2),
#  ('合是', 2),
#  ('0D', 2),
#  ('一看', 2),
#  ('只不过', 2),
#  ('家里人', 2),
#  ('14', 2),
#  ('事后', 2),
#  ('这店', 2),
#  ('本来', 2),
#  ('泡酒', 2),
#  ('鹿茸', 2),
#  ('梳妆台', 2),
#  ('周围', 2),
#  ('人来', 2),
#  ('牛仔', 2),
#  ('蓝花', 2),
#  ('好棒', 2),
#  ('FC', 2),
#  ('奋注', 2),
#  ('送笔', 2),
#  ('仔细检查', 2),
#  ('半斤', 2),
#  ('做好', 2),
#  ('95', 2),
#  ('xz', 2),
#  ('紫菜', 2),
#  ('打款', 2),
#  ('回馈', 2),
#  ('全面', 2),
#  ('建议您', 2),
#  ('收纳盒', 2),
#  ('套餐', 2),
#  ('五种', 2),
#  ('魔音', 2),
#  ('切换', 2),
#  ('清晰', 2),
#  ('厚些', 2),
#  ('说到做到', 2),
#  ('买贵店', 2),
#  ('果冻', 2),
#  ('延时', 2),
#  ('喷剂', 2),
#  ('买套', 2),
#  ('眼袋', 2),
#  ('经验', 2),
#  ('三代', 2),
#  ('的哥', 2),
#  ('要好看', 2),
#  ('0.0', 2),
#  ('鸭蛋', 2),
#  ('不失', 2),
#  ('所望', 2),
#  ('东城区', 2),
#  ('鸿福', 2),
#  ('东路', 2),
#  ('明苑', 2),
#  ('大厦', 2),
#  ('我装', 2),
#  ('好谢', 2),
#  ('相片', 2),
#  ('哈急', 2),
#  ('比赛', 2),
#  ('那好', 2),
#  ('第二件', 2),
#  ('盘时', 2),
#  ('损坏', 2),
#  ('买笔', 2),
#  ('73110424954923', 2),
#  ('模具', 2),
#  ('工具', 2),
#  ('转印', 2),
#  ('画布', 2),
#  ('酱模', 2),
#  ('创意', 2),
#  ('盘饰', 2),
#  ('人生', 2),
#  ('巧克力', 2),
#  ('苦中', 2),
#  ('甜而不腻', 2),
#  ('顺顺利利', 2),
#  ('帮衬', 2),
#  ('防滑', 2),
#  ('有礼', 2),
#  ('超甜', 2),
#  ('来回', 2),
#  ('折腾', 2),
#  ('掌柜', 2),
#  ('再试', 2),
#  ('多长时间', 2),
#  ('五级', 2),
#  ('哈一黑', 2),
#  ('一蓝哈', 2),
#  ('万千', 2),
#  ('不选', 2),
#  ('亲谢', 2),
#  ('花青素', 2),
#  ('精华液', 2),
#  ('能够', 2),
#  ('请返', 2),
#  ('男鞋', 2),
#  ('百搭小白', 2),
#  ('鞋板', 2),
#  ('老爹', 2),
#  ('鞋潮', 2),
#  ('主图', 2),
#  ('真正', 2),
#  ('猫猫', 2),
#  ('星大', 2),
#  ('fan', 2),
#  ('现么', 2),
#  ('别拿错', 2),
#  ('老板娘', 2),
#  ('HAOD', 2),
#  ('闺蜜来', 2),
#  ('有劳', 2),
#  ('元行', 2),
#  ('护手霜', 2),
#  ('超仙', 2),
#  ('交完', 2),
#  ('养好', 2),
#  ('满分', 2),
#  ('FKX00', 2),
#  ('中式', 2),
#  ('烤烟', 2),
#  ('热带', 2),
#  ('蓝莓', 2),
#  ('美观', 2),
#  ('周六', 2),
#  ('中通韵', 2),
#  ('平板', 2),
#  ('A75', 2),
#  ('厂名', 2),
#  ('能减', 2),
#  ('唯美', 2),
#  ('情调', 2),
#  ('女孩子', 2),
#  ('门帘', 2),
#  ('门框', 2),
#  ('外沿', 2),
#  ('地坪', 2),
#  ('高贵', 2),
#  ('是从', 2),
#  ('上边', 2),
#  ('下边', 2),
#  ('折叠为', 2),
#  ('包裙', 2),
#  ('固定', 2),
#  ('韵达', 2),
#  ('成团', 2),
#  ('内会', 2),
#  ('天会', 2),
#  ('浅肤', 2),
#  ('十双', 2),
#  ('豆沙', 2),
#  ('灰十双', 2),
#  ('云纹款', 2),
#  ('款半', 2),
#  ('一根', 2),
#  ('车轴', 2),
#  ('水壶', 2),
#  ('买瑞鑫', 2),
#  ('寿康', 2),
#  ('厂家直销', 2),
#  ('一买', 2),
#  ('换为', 2),
#  ('牌气', 2),
#  ('大姨妈', 2),
#  ('姨夫', 2),
#  ('姑父', 2),
#  ('姑妈', 2),
#  ('爷爷奶奶', 2),
#  ('奖品', 2),
#  ('母亲', 2),
#  ('求快', 2),
#  ('想象', 2),
#  ('好装', 2),
#  ('证件', 2),
#  ('保修卡', 2),
#  ('正式', 2),
#  ('发票', 2),
#  ('面条', 2),
#  ('这鞋', 2),
#  ('袜套', 2),
#  ('儿童', 2),
#  ('护膝', 2),
#  ('带来', 2),
#  ('视觉', 2),
#  ('不大不小', 2),
#  ('隐秘', 2),
#  ('夏至', 2),
#  ('冬至', 2),
#  ('届时', 2),
#  ('温度', 2),
#  ('酒柜', 2),
#  ('之间', 2),
#  ('价款', 2),
#  ('粘性', 2),
#  ('专享', 2),
#  ('反手', 2),
#  ('67kg.175', 2),
#  ('cm.12', 2),
#  ('emm', 2),
#  ('小格格', 2),
#  ('昭阳区', 2),
#  ('很远', 2),
#  ('四十多分钟', 2),
#  ('不腻', 2),
#  ('天用', 2),
#  ('有用', 2),
#  ('家长', 2),
#  ('益气', 2),
#  ('人真', 2),
#  ('评语', 2),
#  ('4F', 2),
#  ('Hi', 2),
#  ('洋灵', 2),
#  ('看吧', 2),
#  ('来领', 2),
#  ('小宝宝', 2),
#  ('买滴', 2),
#  ('乳霜', 2),
#  ('前先用', 2),
#  ('温水', 2),
#  ('塑造', 2),
#  ('取适量', 2),
#  ('本品', 2),
#  ('涂于', 2),
#  ('打圈', 2),
#  ('方式', 2),
#  ('1020', 2),
#  ('直到', 2),
#  ('如需', 2),
#  ('更佳', 2),
#  ('3045', 2),
#  ('小量', 2),
#  ('运动', 2),
#  ('随想', 2),
#  ('好下', 2),
#  ('效率高', 2),
#  ('快稳', 2),
#  ('背心儿', 2),
#  ('女夏', 2),
#  ('半袖', 2),
#  ('印花', 2),
#  ('800', 2),
#  ('发邮玫', 2),
#  ('质量上乘', 2),
#  ('不卡顿', 2),
#  ('画质', 2),
#  ('7p128', 2),
#  ('真有', 2),
#  ('人要', 2),
#  ('劲儿', 2),
#  ('点半前', 2),
#  ('Ha', 2),
#  ('装子弹', 2),
#  ('提示', 2),
#  ('黑糖', 2),
#  ('好些', 2),
#  ('印刷', 2),
#  ('作业本', 2),
#  ('家购', 2),
#  ('纯牛奶', 2),
#  ('好亲', 2),
#  ('慢性', 2),
#  ('狡猾', 2),
#  ('老鼠', 2),
#  ('好开心', 2),
#  ('价格公道', 2),
#  ('家枣', 2),
#  ('EMS', 2),
#  ('240', 2),
#  ('按摩椅', 2),
#  ('x9p', 2),
#  ('总成', 2),
#  ('9.0', 2),
#  ('9k', 2),
#  ('现金', 2),
#  ('3429151', 2),
#  ('大力', 2),
#  ('亲朋好友', 2),
#  ('放好', 2),
#  ('508673130', 2),
#  ('一区', 2),
#  ('等到', 2),
#  ('张挂在', 2),
#  ('尿片', 2),
#  ('香奈儿', 2),
#  ('茉莉花', 2),
#  ('昨天上午', 2),
#  ('2019.3', 2),
#  ('帅哥', 2),
#  ('才行', 2),
#  ('杀虫', 2),
#  ('杀菌', 2),
#  ('冰丝', 2),
#  ('坚果', 2),
#  ('一酱', 2),
#  ('一酒', 2),
#  ('插座', 2),
#  ('洗脸盆', 2),
#  ('浴室柜', 2),
#  ('因宝', 2),
#  ('祝龙', 2),
#  ('几本', 2),
#  ('6080', 2),
#  ('造型', 2),
#  ('时看', 2),
#  ('商品质量', 2),
#  ('季节', 2),
#  ('温和', 2),
#  ('7.9', 2),
#  ('豹纹', 2),
#  ('59', 2),
#  ('真心话', 2),
#  ('304', 2),
#  ('长大', 2),
#  ('优秀', 2),
#  ('欣欣', 2),
#  ('剪刀', 2),
#  ('給你', 2),
#  ('那祝', 2),
#  ('稀有', 2),
#  ('活物', 2),
#  ('单只', 2),
#  ('银狐', 2),
#  ('幼崽', 2),
#  ('巨型', 2),
#  ('宠物', 2),
#  ('小型', 2),
#  ('好养', 2),
#  ('苍鼠', 2),
#  ('是不是', 2),
#  ('拍点', 2),
#  ('大颗', 2),
#  ('工装', 2),
#  ('夹克', 2),
#  ('褂子', 2),
#  ('三套', 2),
#  ('皮带', 2),
#  ('心愿', 2),
#  ('父母', 2),
#  ('妻子', 2),
#  ('沟通', 2),
#  ('坐套', 2),
#  ('水箱', 2),
#  ('五块', 2),
#  ('卖完', 2),
#  ('先好', 2),
#  ('邻居', 2),
#  ('QwQ', 2),
#  ('芋头', 2),
#  ('好查', 2),
#  ('LHL', 2),
#  ('薄款', 2),
#  ('好保', 2),
#  ('排油', 2),
#  ('减脂', 2),
#  ('看出', 2),
#  ('湿气', 2),
#  ('刚取', 2),
#  ('身高', 2),
#  ('选选', 2),
#  ('仔细', 2),
#  ('米够', 2),
#  ('一名', 2),
#  ('主播', 2),
#  ('YES', 2),
#  ('刮刮卡', 2),
#  ('有关', 2),
#  ('亮肤', 2),
#  ('保暖', 2),
#  ('恰好', 2),
#  ('亲家母', 2),
#  ('朋长', 2),
#  ('不胜', 2),
#  ('61206020', 2),
#  ('调试', 2),
#  ('吃饭', 2),
#  ('听说', 2),
#  ('昆吾戒', 2),
#  ('黄金', 2),
#  ('模仿', 2),
#  ('真烟', 2),
#  ('陈皮', 2),
#  ('香气', 2),
#  ('微微', 2),
#  ('薄荷', 2),
#  ('细支', 2),
#  ('温碧泉', 2),
#  ('自从', 2),
#  ('姑娘', 2),
#  ('211115111', 2),
#  ('弥漫', 2),
#  ('本网页', 2),
#  ('369', 2),
#  ('确保', 2),
#  ('买不到', 2),
#  ('帘子', 2),
#  ('安好', 2),
#  ('朋友圈', 2),
#  ('发好', 2),
#  ('美美', 2),
#  ('照像馆', 2),
#  ('不二', 2),
#  ('直冲', 2),
#  ('别发韵', 2),
#  ('达哈', 2),
#  ('Camel', 2),
#  ('骆驼', 2),
#  ('男女', 2),
#  ('户外', 2),
#  ('跑鞋', 2),
#  ('潮鞋', 2),
#  ('春秋季', 2),
#  ('大码', 2),
#  ('圆领', 2),
#  ('长袖', 2),
#  ('卫衣', 2),
#  ('定单', 2),
#  ('差不多', 2),
#  ('补个', 2),
#  ('钢化', 2),
#  ('民国', 2),
#  ('改良', 2),
#  ('盘扣', 2),
#  ('绣花', 2),
#  ('初秋', 2),
#  ('夏装', 2),
#  ('棉麻', 2),
#  ('拉拉', 2),
#  ('8B', 2),
#  ('附带', 2),
#  ('火锅', 2),
#  ('底料', 2),
#  ('二包', 2),
#  ('XL', 2),
#  ('湿纸', 2),
#  ('避孕套', 2),
#  ('情趣', 2),
#  ('润滑', 2),
#  ('啫喱', 2),
#  ('横刻', 2),
#  ('身中', 2),
#  ('佳雨', 2),
#  ('专属', 2),
#  ('书写', 2),
#  ('与众不同', 2),
#  ('加追平', 2),
#  ('三盒', 2),
#  ('没来', 2),
#  ('插口', 2),
#  ('无光', 2),
#  ('夜视', 2),
#  ('Niha', 2),
#  ('最亲', 2),
#  ('要装', 2),
#  ('体面', 2),
#  ('真品', 2),
#  ('礼拜六', 2),
#  ('点歌', 2),
#  ('真材实料', 2),
#  ('冷过', 2),
#  ('城区', 2),
#  ('丽江', 2),
#  ('复购', 2),
#  ('1.67', 2),
#  ('四件套', 2),
#  ('购进', 2),
#  ('謝謝', 2),
#  ('增氧', 2),
#  ('流行', 2),
#  ('chic', 2),
#  ('裙春', 2),
#  ('七分', 2),
#  ('夏潮', 2),
#  ('好了吧', 2),
#  ('戴荣', 2),
#  ('赞亲', 2),
#  ('江苏省', 2),
#  ('南京市', 2),
#  ('六合区', 2),
#  ('葛塘', 2),
#  ('和平', 2),
#  ('社区', 2),
#  ('大包', 2),
#  ('142', 2),
#  ('树下果', 2),
#  ('襄汾', 2),
#  ('买点儿', 2),
#  ...]

# %%
split_list=[]
for item in x_train:
    a=dividesentence(item)
    split_list.append(a)

# %%
# 初始化两个token：pad和unk
vocab = ["<pad>", "<unk>"]

# 去除出现频次为1次的单词
# 去除出现频次为1次的单词
for w, f in c.most_common():
    if f > 1:
        vocab.append(w)

# %%
print("The total size of our vocabulary is: {}".format(len(vocab)))
# Out:
# The total size of our vocabulary is: 4116

# %%
vocab
# Out:
# ['<pad>',
#  '<unk>',
#  '谢谢',
#  '好评',
#  '五星',
#  '下次',
#  'OK',
#  '不错',
#  '东西',
#  '网页',
#  '收到',
#  '发货',
#  '一定',
#  '上次',
#  '你家',
#  '下单',
#  '质量',
#  '可以',
#  '微信',
#  '号码',
#  '已经',
#  '之前',
#  '一个',
#  '满意',
#  '生意兴隆',
#  '还会',
#  '喜欢',
#  '老板',
#  '不过',
#  '尽快',
#  '购买',
#  '收藏',
#  '非常',
#  '希望',
#  '产品',
#  '的话',
#  '亲亲',
#  '光顾',
#  '朋友',
#  '继续',
#  '不好意思',
#  '好吃',
#  '回购',
#  '一下',
#  '感谢',
#  '效果',
#  '买过',
#  '以后',
#  '快递',
#  '衣服',
#  '还来',
#  '记得',
#  '真的',
#  '需要',
#  '我会',
#  '你们',
#  '推荐',
#  '今天',
#  '你好',
#  '备注',
#  '我们',
#  '检查',
#  '晒图',
#  '如果',
#  '感觉',
#  '介绍',
#  '争取',
#  '中通',
#  '不用',
#  '谢谢您',
#  '这个',
#  '店铺',
#  '一件',
#  '评价',
#  '还是',
#  'Ok',
#  '多谢',
#  '还会来',
#  '两个',
#  '一样',
#  '好用',
#  '特别',
#  '明天',
#  '确实',
#  '0K',
#  '亲好',
#  '下午',
#  '一直',
#  '包装',
#  '试试',
#  '帮忙',
#  '宝贝',
#  '颜色',
#  '期待',
#  '一次',
#  '快点',
#  '非常感谢',
#  '好看',
#  '服务',
#  '哈哈哈',
#  '主要',
#  '手机号码',
#  '&#',
#  'HTTPS',
#  'QR',
#  'COM',
#  '觉得',
#  '早点',
#  '安排',
#  '万分',
#  'kk',
#  '一起',
#  '合适',
#  '优惠',
#  '这次',
#  '买好',
#  '舒服',
#  '店家',
#  '裤子',
#  '光临',
#  '现在',
#  '几天',
#  '合作愉快',
#  '邮政',
#  '所以',
#  '鞋子',
#  '一套',
#  '到货',
#  '成功',
#  '很漂亮',
#  '合作',
#  '一双',
#  '追加',
#  '34',
#  '保证质量',
#  '追评',
#  '链接',
#  '最好',
#  '好好',
#  '刚刚',
#  '挺好用',
#  '两件',
#  '麻烦',
#  '嘻嘻',
#  '正品',
#  '一条',
#  '很快',
#  '评论',
#  '点击',
#  '那个',
#  '不会',
#  '挺好吃',
#  '方便',
#  '手机',
#  '一瓶',
#  '选择',
#  '红包',
#  '不用谢',
#  '穿着',
#  '孩子',
#  '漂亮',
#  '还要',
#  '服务态度',
#  '民族',
#  '到时候',
#  '商品',
#  '愉快',
#  '这么',
#  '放心',
#  '一点',
#  '同事',
#  '祝您',
#  '不要',
#  '别忘了',
#  '马上',
#  '打开',
#  '合身',
#  '再次',
#  '收货',
#  '下回',
#  '支持',
#  '二次',
#  '2019',
#  '安装',
#  '生意',
#  '商家',
#  '挺不错',
#  '0k',
#  '使用',
#  '比较',
#  '回来',
#  '复制',
#  '实惠',
#  '买来',
#  '味道',
#  '态度',
#  '这里',
#  '三个',
#  '这边',
#  '多多',
#  '拼单',
#  '买点',
#  '返现',
#  '面膜',
#  '一会',
#  '物流',
#  '尽量',
#  '也好',
#  '辛苦',
#  '时间',
#  '哈哈',
#  '财源',
#  '疗程',
#  '要是',
#  '起来',
#  '生日快乐',
#  '几次',
#  '还有',
#  '一包',
#  '本店',
#  '一如既往',
#  '关注',
#  '知道',
#  'OKOK',
#  '学生',
#  '值得',
#  '客服',
#  '看到',
#  '广进',
#  '奖励',
#  '谢谢你们',
#  '必须',
#  '第二次',
#  '应该',
#  '签收',
#  '39',
#  '给你个',
#  '15',
#  '感恩',
#  '机会',
#  '韩版',
#  '因为',
#  '付款',
#  '查看',
#  '开心',
#  '云南省',
#  '长期',
#  '再来',
#  '一款',
#  '可爱',
#  '操作',
#  '两双',
#  '健康',
#  '买回来',
#  '新鲜',
#  '完成',
#  '多少',
#  '五分',
#  '肯定',
#  '好点',
#  '财源滚滚',
#  '准备',
#  '小姐姐',
#  '红色',
#  '感谢您',
#  '表情',
#  '中午',
#  '这款',
#  '一些',
#  '晚上',
#  '就行',
#  '亲爱',
#  '刚好',
#  '保证',
#  '日期',
#  '几个',
#  '耐心',
#  '仙女',
#  '价格',
#  '新款',
#  '只要',
#  '绝对',
#  '10',
#  '客气',
#  '生活',
#  '保密',
#  '抓紧',
#  '速度',
#  '加油',
#  '一对',
#  '没有',
#  '小孩',
#  '截图',
#  '宝宝',
#  '拿到',
#  '好多',
#  '100',
#  '美丽',
#  '一切',
#  '越来越',
#  '多送',
#  '试一下',
#  '试试看',
#  '视频',
#  '质量保证',
#  '一箱',
#  '优惠券',
#  '就行了',
#  '耳机',
#  '50',
#  '亲已',
#  '联系',
#  '图片',
#  '好会',
#  '一盒',
#  '看着',
#  '20',
#  '浏览器',
#  '太好了',
#  '两套',
#  '自然',
#  '赶紧',
#  '下载',
#  '大小',
#  'ha',
#  '五颗星',
#  '想要',
#  '我家',
#  '购物',
#  '最佳',
#  '试用',
#  '好喝',
#  '提取',
#  '口感',
#  '产后',
#  '快快',
#  '而且',
#  '便宜',
#  '两次',
#  '的确',
#  '完美',
#  '时尚',
#  '忘记',
#  '送点',
#  '店里',
#  '有没有',
#  '礼品',
#  '老公',
#  '密码',
#  '点赞',
#  '好哈',
#  '还好',
#  '两瓶',
#  '其他',
#  '分享',
#  '检查一下',
#  '这段',
#  '描述',
#  '妈妈',
#  '祝福',
#  '家里',
#  '这件',
#  '客户',
#  '水果',
#  '他们',
#  '这样',
#  '这种',
#  '祝你们',
#  '女儿',
#  '大概',
#  '真心',
#  '很棒',
#  '打算',
#  '完单',
#  '五元',
#  '惊喜',
#  '内容',
#  '百度网',
#  '款式',
#  '恭喜发财',
#  '地址',
#  '晚安',
#  '一天',
#  '下周',
#  'mua',
#  '装好',
#  '诚信',
#  '确认',
#  '时候',
#  '结实',
#  '指导',
#  '一袋',
#  '发中通',
#  '每天',
#  '昨天',
#  '码穿',
#  '很正',
#  '但愿',
#  'Okk',
#  '添麻烦',
#  '解答',
#  '真不错',
#  '上午',
#  '搞定',
#  '了解',
#  '一支',
#  '清单',
#  '减肥',
#  '几盒',
#  '12',
#  '看好',
#  '快乐',
#  '所有',
#  '鼓励',
#  '点亮',
#  '兴隆',
#  '工作',
#  '信任',
#  '充电',
#  '赶快',
#  '之后',
#  '袜子',
#  '信誉',
#  '两箱',
#  '老师',
#  '家电',
#  '黑色',
#  '看起来',
#  '问题',
#  '开始',
#  '500',
#  'App',
#  '不谢',
#  '贵店',
#  '男士',
#  '亲发',
#  '两包',
#  '音质',
#  '祝亲',
#  '先买',
#  '多次',
#  '杯子',
#  '下好',
#  '五条',
#  '一年',
#  '卖家',
#  '不管怎样',
#  '就要',
#  '书包',
#  '几件',
#  '补水',
#  '货到',
#  '平安',
#  '老婆',
#  '打扰',
#  '咱家',
#  '活动',
#  '账号',
#  '最近',
#  '儿子',
#  '好玩',
#  '上面',
#  '老乡',
#  '24',
#  '小时',
#  '赠品',
#  '过来',
#  '一共',
#  '产品质量',
#  '上身',
#  '有效',
#  '三次',
#  '杠杠',
#  '学习',
#  '生日',
#  '东莞市',
#  '快件',
#  '东莞',
#  '疑问请',
#  '电联',
#  '妥投',
#  '感到',
#  '员处',
#  '一单',
#  '毫升',
#  '宽松',
#  '上衣',
#  '并且',
#  '清洗',
#  '只是',
#  '型号',
#  '有点',
#  '亲人',
#  '不知',
#  '111',
#  '淘宝',
#  '看看',
#  '多买',
#  '以上',
#  '回头',
#  '一本',
#  '一份',
#  '顺利',
#  '多久',
#  '送到',
#  '买二送',
#  '16',
#  '左右',
#  '早上',
#  '电话',
#  '不错呀',
#  '为了',
#  '32',
#  '百搭',
#  '亲到',
#  '上海',
#  '公举',
#  '赠送',
#  '送给',
#  '160',
#  '身边',
#  '个人',
#  '货真价实',
#  '上班',
#  '口味',
#  '保持',
#  '更好',
#  '老爸',
#  '挺舒服',
#  '跑步机',
#  '身体健康',
#  '五星级',
#  '三件',
#  '130',
#  '五个',
#  '清楚',
#  '纯棉',
#  '惠顾',
#  '再购',
#  '套装',
#  'gt',
#  '完好',
#  '透气',
#  '拍下',
#  '休闲',
#  '个性',
#  '补发',
#  '亲们',
#  '学校',
#  '正在',
#  '适合',
#  '幸福',
#  '礼物',
#  '理解',
#  '第一次',
#  '2009',
#  '保湿',
#  '做工',
#  '周期',
#  '换成',
#  '三天',
#  '送上',
#  '经常',
#  '140',
#  '拜托',
#  '一张',
#  '正好',
#  '今天下午',
#  '我爱你',
#  '文字',
#  '天天',
#  '圆通',
#  '品质',
#  'QQ',
#  '即可',
#  '丑橘',
#  '别人',
#  '帽子',
#  '耐用',
#  '善良',
#  '聪明',
#  '谢谢合作',
#  '安全',
#  '买件',
#  '一百个',
#  '宣传',
#  '厨房',
#  '配件',
#  '里面',
#  '给力',
#  '果子',
#  '长安',
#  '门卫',
#  '076981669939',
#  '20190318',
#  '夏季',
#  '提高',
#  '销量',
#  '棒棒',
#  '首选',
#  '以前',
#  '加购',
#  '功效',
#  '真好',
#  '18',
#  '您好',
#  '是否',
#  '发大财',
#  '东北',
#  '好使',
#  '处理',
#  '顾客',
#  '打错字',
#  '旗舰店',
#  '亲请',
#  '再说',
#  '爸爸',
#  '用过',
#  '小米',
#  '五双',
#  '热水器',
#  '油烟机',
#  '洗衣机',
#  '使用寿命',
#  '放在',
#  '那种',
#  '优先',
#  '关顾',
#  '注意',
#  '大家',
#  '超级',
#  '正合适',
#  '春季',
#  '休闲鞋',
#  '怎么样',
#  '暖和',
#  '登记',
#  '云南',
#  '面部',
#  '万事如意',
#  '贺卡',
#  '超好',
#  '充电器',
#  '代餐',
#  '打包',
#  '货己',
#  '每次',
#  '家买',
#  '物美价廉',
#  '硅油',
#  '减震',
#  '手感',
#  '百度',
#  '坚持',
#  'lt',
#  '种子',
#  '女孩',
#  '不累',
#  '女人',
#  '快速',
#  '两条',
#  '能否',
#  '永远',
#  '尺码',
#  '标准',
#  '自己',
#  '美女',
#  '电脑',
#  '三元',
#  '经络',
#  '简单',
#  '咱们',
#  '可能',
#  '旗袍',
#  '及时',
#  '失望',
#  '选购',
#  '一生',
#  '街道',
#  '中药',
#  '海藻',
#  '方法',
#  '别的',
#  '亲刚',
#  '迫不及待',
#  '面料',
#  '红河州',
#  '订单',
#  '减了',
#  '亲给',
#  '互相',
#  '帮助',
#  '实用',
#  '很多',
#  '提醒',
#  '买一送一',
#  '尺寸',
#  '懒人',
#  '丝巾',
#  '领取',
#  '到位',
#  '货好',
#  '售后',
#  '苹果',
#  '外套',
#  '刚才',
#  '两大瓶',
#  '网址',
#  '姐妹',
#  '急用',
#  '没事',
#  '砍价',
#  '免费',
#  '选好',
#  '3D',
#  '注册',
#  '查收',
#  '两盒',
#  '超爱',
#  '如初',
#  '公主',
#  '一位',
#  '人见人爱',
#  '花见',
#  '花开',
#  '备受',
#  '赞叹',
#  '美少女',
#  '钟晴',
#  '纯中药',
#  '黑头',
#  '去屑',
#  '40',
#  '大大的',
#  '邮箱',
#  '勺子',
#  '京东',
#  '越做越',
#  '一波',
#  '找到',
#  '新房',
#  '放单',
#  '到来',
#  '退款',
#  '欢迎',
#  '七彩',
#  '礼盒',
#  '健身',
#  '太棒了',
#  '过程',
#  '掉色',
#  '起球',
#  '物有所值',
#  '买花',
#  '相信',
#  '内衣',
#  '不是',
#  '下雪',
#  '核桃',
#  '事情',
#  '回头客',
#  '容易',
#  '橙子',
#  '二十',
#  '88',
#  '红火',
#  '生日礼物',
#  '发件',
#  '中奖',
#  '开花',
#  '把关',
#  '买个',
#  '电视',
#  '马桶',
#  '维修',
#  '专业',
#  '空调',
#  '冰箱',
#  '过后',
#  '然后',
#  '着急',
#  '雨衣',
#  '厚实',
#  '小巧',
#  '发给',
#  '周日',
#  '我发',
#  '一年四季',
#  '大哥',
#  '精酿',
#  '啤酒',
#  '优质',
#  '优惠价',
#  '那就好',
#  't95r',
#  '已到',
#  '店主',
#  '潮流',
#  '真是',
#  '天气',
#  '手套',
#  '补偿',
#  'CC',
#  '粉色',
#  '一家人',
#  '这是',
#  '完好无损',
#  '姐姐',
#  '不能',
#  '挑选',
#  '采购',
#  '只有',
#  '挑好',
#  '女神',
#  '同学',
#  '中学',
#  '享受',
#  '好几个',
#  '公分',
#  '起到',
#  '保护',
#  '折叠',
#  '课程',
#  '不发',
#  '礼包',
#  '连衣裙',
#  '轻柔',
#  '师傅',
#  '包包',
#  '优惠活动',
#  '告诉',
#  '已买',
#  '不锈钢',
#  '一家',
#  '好滴',
#  '一盆',
#  '小美女',
#  '一块',
#  '百世',
#  '试吃',
#  '...',
#  '90',
#  '犹豫',
#  '升级',
#  '更加',
#  '怎样',
#  '美容',
#  '两件套',
#  '不聊',
#  '帅气',
#  '毛孔',
#  'ins',
#  'OKK',
#  '内裤',
#  '好几家',
#  '110',
#  '多虑',
#  '喝完',
#  '省力',
#  '需要的话',
#  '春秋',
#  '卡通',
#  '红红火火',
#  '三双',
#  '排毒',
#  '装在',
#  '分钟',
#  'bf',
#  '人好',
#  '一发',
#  '抱歉',
#  '没买错',
#  '十斤',
#  '再会',
#  '娘家',
#  '我查',
#  '丽江市',
#  '一岁',
#  '一会儿',
#  '情侣',
#  '促进',
#  '担心',
#  '亲以',
#  '试一试',
#  '补肾',
#  '120',
#  '视频教程',
#  '不贵',
#  '我用',
#  '认定',
#  '照片',
#  '第三次',
#  '好运',
#  '下面',
#  '裙子',
#  '拍照',
#  '脸部',
#  '30',
#  '眼睛',
#  '会常来',
#  '发送',
#  '紧绷',
#  '橘子',
#  '码数',
#  '28',
#  '料子',
#  '贵州省',
#  '贵阳市',
#  '花溪区',
#  '超市',
#  '亲能',
#  '没关系',
#  '19',
#  '一棵',
#  '两袋',
#  '白色',
#  '十分',
#  '过生日',
#  'vip',
#  '成活率',
#  '外用',
#  'nice',
#  '平台',
#  '信息',
#  '干净',
#  '爱车',
#  '老客户',
#  '直接',
#  '兄弟',
#  '喷雾',
#  '搭配',
#  '总是',
#  '每年',
#  '电池',
#  '300',
#  '五心',
#  '戒指',
#  '白皙',
#  '品相',
#  '买些',
#  '配合',
#  '好友',
#  '巩固',
#  '不少',
#  '回复',
#  '发芽',
#  '买鞋',
#  '哪种',
#  '三张',
#  '调理',
#  '买到',
#  '蒙自',
#  '支架',
#  '保质保量',
#  '电动',
#  '千玺',
#  '进去',
#  '那里',
#  '蜂蜜',
#  '加厚',
#  '房子',
#  '精选',
#  '保驾护航',
#  '好货',
#  '大吉',
#  'APP',
#  '流畅',
#  '充值',
#  '时时',
#  '分分',
#  '11',
#  '代理',
#  '眼镜',
#  '亲拍',
#  'T1',
#  '女友',
#  '亲要',
#  '温柔',
#  '单独',
#  '呵呵',
#  '经济',
#  '三种',
#  '代购',
#  '极好',
#  '坐等',
#  '恩恩',
#  '严格',
#  '两桶',
#  '慧美纹',
#  '点穴',
#  '饮食',
#  '慧美',
#  '祛斑',
#  '祛痘',
#  '热线',
#  '19825859936',
#  '丝滑',
#  '提升',
#  '这家',
#  '凳子',
#  ...]

# %% [markdown]
# ### 构建映射

# %%
# 单词到编码的映射，例如machine -> 4116
word_to_token = {word: token for token, word in enumerate(vocab)}
# 编码到单词的映射，例如3057 -> machineb
token_to_word = {token: word for word, token in word_to_token.items()}

# %%
word_to_token
# Out:
# {'<pad>': 0,
#  '<unk>': 1,
#  '谢谢': 2,
#  '好评': 3,
#  '五星': 4,
#  '下次': 5,
#  'OK': 6,
#  '不错': 7,
#  '东西': 8,
#  '网页': 9,
#  '收到': 10,
#  '发货': 11,
#  '一定': 12,
#  '上次': 13,
#  '你家': 14,
#  '下单': 15,
#  '质量': 16,
#  '可以': 17,
#  '微信': 18,
#  '号码': 19,
#  '已经': 20,
#  '之前': 21,
#  '一个': 22,
#  '满意': 23,
#  '生意兴隆': 24,
#  '还会': 25,
#  '喜欢': 26,
#  '老板': 27,
#  '不过': 28,
#  '尽快': 29,
#  '购买': 30,
#  '收藏': 31,
#  '非常': 32,
#  '希望': 33,
#  '产品': 34,
#  '的话': 35,
#  '亲亲': 36,
#  '光顾': 37,
#  '朋友': 38,
#  '继续': 39,
#  '不好意思': 40,
#  '好吃': 41,
#  '回购': 42,
#  '一下': 43,
#  '感谢': 44,
#  '效果': 45,
#  '买过': 46,
#  '以后': 47,
#  '快递': 48,
#  '衣服': 49,
#  '还来': 50,
#  '记得': 51,
#  '真的': 52,
#  '需要': 53,
#  '我会': 54,
#  '你们': 55,
#  '推荐': 56,
#  '今天': 57,
#  '你好': 58,
#  '备注': 59,
#  '我们': 60,
#  '检查': 61,
#  '晒图': 62,
#  '如果': 63,
#  '感觉': 64,
#  '介绍': 65,
#  '争取': 66,
#  '中通': 67,
#  '不用': 68,
#  '谢谢您': 69,
#  '这个': 70,
#  '店铺': 71,
#  '一件': 72,
#  '评价': 73,
#  '还是': 74,
#  'Ok': 75,
#  '多谢': 76,
#  '还会来': 77,
#  '两个': 78,
#  '一样': 79,
#  '好用': 80,
#  '特别': 81,
#  '明天': 82,
#  '确实': 83,
#  '0K': 84,
#  '亲好': 85,
#  '下午': 86,
#  '一直': 87,
#  '包装': 88,
#  '试试': 89,
#  '帮忙': 90,
#  '宝贝': 91,
#  '颜色': 92,
#  '期待': 93,
#  '一次': 94,
#  '快点': 95,
#  '非常感谢': 96,
#  '好看': 97,
#  '服务': 98,
#  '哈哈哈': 99,
#  '主要': 100,
#  '手机号码': 101,
#  '&#': 102,
#  'HTTPS': 103,
#  'QR': 104,
#  'COM': 105,
#  '觉得': 106,
#  '早点': 107,
#  '安排': 108,
#  '万分': 109,
#  'kk': 110,
#  '一起': 111,
#  '合适': 112,
#  '优惠': 113,
#  '这次': 114,
#  '买好': 115,
#  '舒服': 116,
#  '店家': 117,
#  '裤子': 118,
#  '光临': 119,
#  '现在': 120,
#  '几天': 121,
#  '合作愉快': 122,
#  '邮政': 123,
#  '所以': 124,
#  '鞋子': 125,
#  '一套': 126,
#  '到货': 127,
#  '成功': 128,
#  '很漂亮': 129,
#  '合作': 130,
#  '一双': 131,
#  '追加': 132,
#  '34': 133,
#  '保证质量': 134,
#  '追评': 135,
#  '链接': 136,
#  '最好': 137,
#  '好好': 138,
#  '刚刚': 139,
#  '挺好用': 140,
#  '两件': 141,
#  '麻烦': 142,
#  '嘻嘻': 143,
#  '正品': 144,
#  '一条': 145,
#  '很快': 146,
#  '评论': 147,
#  '点击': 148,
#  '那个': 149,
#  '不会': 150,
#  '挺好吃': 151,
#  '方便': 152,
#  '手机': 153,
#  '一瓶': 154,
#  '选择': 155,
#  '红包': 156,
#  '不用谢': 157,
#  '穿着': 158,
#  '孩子': 159,
#  '漂亮': 160,
#  '还要': 161,
#  '服务态度': 162,
#  '民族': 163,
#  '到时候': 164,
#  '商品': 165,
#  '愉快': 166,
#  '这么': 167,
#  '放心': 168,
#  '一点': 169,
#  '同事': 170,
#  '祝您': 171,
#  '不要': 172,
#  '别忘了': 173,
#  '马上': 174,
#  '打开': 175,
#  '合身': 176,
#  '再次': 177,
#  '收货': 178,
#  '下回': 179,
#  '支持': 180,
#  '二次': 181,
#  '2019': 182,
#  '安装': 183,
#  '生意': 184,
#  '商家': 185,
#  '挺不错': 186,
#  '0k': 187,
#  '使用': 188,
#  '比较': 189,
#  '回来': 190,
#  '复制': 191,
#  '实惠': 192,
#  '买来': 193,
#  '味道': 194,
#  '态度': 195,
#  '这里': 196,
#  '三个': 197,
#  '这边': 198,
#  '多多': 199,
#  '拼单': 200,
#  '买点': 201,
#  '返现': 202,
#  '面膜': 203,
#  '一会': 204,
#  '物流': 205,
#  '尽量': 206,
#  '也好': 207,
#  '辛苦': 208,
#  '时间': 209,
#  '哈哈': 210,
#  '财源': 211,
#  '疗程': 212,
#  '要是': 213,
#  '起来': 214,
#  '生日快乐': 215,
#  '几次': 216,
#  '还有': 217,
#  '一包': 218,
#  '本店': 219,
#  '一如既往': 220,
#  '关注': 221,
#  '知道': 222,
#  'OKOK': 223,
#  '学生': 224,
#  '值得': 225,
#  '客服': 226,
#  '看到': 227,
#  '广进': 228,
#  '奖励': 229,
#  '谢谢你们': 230,
#  '必须': 231,
#  '第二次': 232,
#  '应该': 233,
#  '签收': 234,
#  '39': 235,
#  '给你个': 236,
#  '15': 237,
#  '感恩': 238,
#  '机会': 239,
#  '韩版': 240,
#  '因为': 241,
#  '付款': 242,
#  '查看': 243,
#  '开心': 244,
#  '云南省': 245,
#  '长期': 246,
#  '再来': 247,
#  '一款': 248,
#  '可爱': 249,
#  '操作': 250,
#  '两双': 251,
#  '健康': 252,
#  '买回来': 253,
#  '新鲜': 254,
#  '完成': 255,
#  '多少': 256,
#  '五分': 257,
#  '肯定': 258,
#  '好点': 259,
#  '财源滚滚': 260,
#  '准备': 261,
#  '小姐姐': 262,
#  '红色': 263,
#  '感谢您': 264,
#  '表情': 265,
#  '中午': 266,
#  '这款': 267,
#  '一些': 268,
#  '晚上': 269,
#  '就行': 270,
#  '亲爱': 271,
#  '刚好': 272,
#  '保证': 273,
#  '日期': 274,
#  '几个': 275,
#  '耐心': 276,
#  '仙女': 277,
#  '价格': 278,
#  '新款': 279,
#  '只要': 280,
#  '绝对': 281,
#  '10': 282,
#  '客气': 283,
#  '生活': 284,
#  '保密': 285,
#  '抓紧': 286,
#  '速度': 287,
#  '加油': 288,
#  '一对': 289,
#  '没有': 290,
#  '小孩': 291,
#  '截图': 292,
#  '宝宝': 293,
#  '拿到': 294,
#  '好多': 295,
#  '100': 296,
#  '美丽': 297,
#  '一切': 298,
#  '越来越': 299,
#  '多送': 300,
#  '试一下': 301,
#  '试试看': 302,
#  '视频': 303,
#  '质量保证': 304,
#  '一箱': 305,
#  '优惠券': 306,
#  '就行了': 307,
#  '耳机': 308,
#  '50': 309,
#  '亲已': 310,
#  '联系': 311,
#  '图片': 312,
#  '好会': 313,
#  '一盒': 314,
#  '看着': 315,
#  '20': 316,
#  '浏览器': 317,
#  '太好了': 318,
#  '两套': 319,
#  '自然': 320,
#  '赶紧': 321,
#  '下载': 322,
#  '大小': 323,
#  'ha': 324,
#  '五颗星': 325,
#  '想要': 326,
#  '我家': 327,
#  '购物': 328,
#  '最佳': 329,
#  '试用': 330,
#  '好喝': 331,
#  '提取': 332,
#  '口感': 333,
#  '产后': 334,
#  '快快': 335,
#  '而且': 336,
#  '便宜': 337,
#  '两次': 338,
#  '的确': 339,
#  '完美': 340,
#  '时尚': 341,
#  '忘记': 342,
#  '送点': 343,
#  '店里': 344,
#  '有没有': 345,
#  '礼品': 346,
#  '老公': 347,
#  '密码': 348,
#  '点赞': 349,
#  '好哈': 350,
#  '还好': 351,
#  '两瓶': 352,
#  '其他': 353,
#  '分享': 354,
#  '检查一下': 355,
#  '这段': 356,
#  '描述': 357,
#  '妈妈': 358,
#  '祝福': 359,
#  '家里': 360,
#  '这件': 361,
#  '客户': 362,
#  '水果': 363,
#  '他们': 364,
#  '这样': 365,
#  '这种': 366,
#  '祝你们': 367,
#  '女儿': 368,
#  '大概': 369,
#  '真心': 370,
#  '很棒': 371,
#  '打算': 372,
#  '完单': 373,
#  '五元': 374,
#  '惊喜': 375,
#  '内容': 376,
#  '百度网': 377,
#  '款式': 378,
#  '恭喜发财': 379,
#  '地址': 380,
#  '晚安': 381,
#  '一天': 382,
#  '下周': 383,
#  'mua': 384,
#  '装好': 385,
#  '诚信': 386,
#  '确认': 387,
#  '时候': 388,
#  '结实': 389,
#  '指导': 390,
#  '一袋': 391,
#  '发中通': 392,
#  '每天': 393,
#  '昨天': 394,
#  '码穿': 395,
#  '很正': 396,
#  '但愿': 397,
#  'Okk': 398,
#  '添麻烦': 399,
#  '解答': 400,
#  '真不错': 401,
#  '上午': 402,
#  '搞定': 403,
#  '了解': 404,
#  '一支': 405,
#  '清单': 406,
#  '减肥': 407,
#  '几盒': 408,
#  '12': 409,
#  '看好': 410,
#  '快乐': 411,
#  '所有': 412,
#  '鼓励': 413,
#  '点亮': 414,
#  '兴隆': 415,
#  '工作': 416,
#  '信任': 417,
#  '充电': 418,
#  '赶快': 419,
#  '之后': 420,
#  '袜子': 421,
#  '信誉': 422,
#  '两箱': 423,
#  '老师': 424,
#  '家电': 425,
#  '黑色': 426,
#  '看起来': 427,
#  '问题': 428,
#  '开始': 429,
#  '500': 430,
#  'App': 431,
#  '不谢': 432,
#  '贵店': 433,
#  '男士': 434,
#  '亲发': 435,
#  '两包': 436,
#  '音质': 437,
#  '祝亲': 438,
#  '先买': 439,
#  '多次': 440,
#  '杯子': 441,
#  '下好': 442,
#  '五条': 443,
#  '一年': 444,
#  '卖家': 445,
#  '不管怎样': 446,
#  '就要': 447,
#  '书包': 448,
#  '几件': 449,
#  '补水': 450,
#  '货到': 451,
#  '平安': 452,
#  '老婆': 453,
#  '打扰': 454,
#  '咱家': 455,
#  '活动': 456,
#  '账号': 457,
#  '最近': 458,
#  '儿子': 459,
#  '好玩': 460,
#  '上面': 461,
#  '老乡': 462,
#  '24': 463,
#  '小时': 464,
#  '赠品': 465,
#  '过来': 466,
#  '一共': 467,
#  '产品质量': 468,
#  '上身': 469,
#  '有效': 470,
#  '三次': 471,
#  '杠杠': 472,
#  '学习': 473,
#  '生日': 474,
#  '东莞市': 475,
#  '快件': 476,
#  '东莞': 477,
#  '疑问请': 478,
#  '电联': 479,
#  '妥投': 480,
#  '感到': 481,
#  '员处': 482,
#  '一单': 483,
#  '毫升': 484,
#  '宽松': 485,
#  '上衣': 486,
#  '并且': 487,
#  '清洗': 488,
#  '只是': 489,
#  '型号': 490,
#  '有点': 491,
#  '亲人': 492,
#  '不知': 493,
#  '111': 494,
#  '淘宝': 495,
#  '看看': 496,
#  '多买': 497,
#  '以上': 498,
#  '回头': 499,
#  '一本': 500,
#  '一份': 501,
#  '顺利': 502,
#  '多久': 503,
#  '送到': 504,
#  '买二送': 505,
#  '16': 506,
#  '左右': 507,
#  '早上': 508,
#  '电话': 509,
#  '不错呀': 510,
#  '为了': 511,
#  '32': 512,
#  '百搭': 513,
#  '亲到': 514,
#  '上海': 515,
#  '公举': 516,
#  '赠送': 517,
#  '送给': 518,
#  '160': 519,
#  '身边': 520,
#  '个人': 521,
#  '货真价实': 522,
#  '上班': 523,
#  '口味': 524,
#  '保持': 525,
#  '更好': 526,
#  '老爸': 527,
#  '挺舒服': 528,
#  '跑步机': 529,
#  '身体健康': 530,
#  '五星级': 531,
#  '三件': 532,
#  '130': 533,
#  '五个': 534,
#  '清楚': 535,
#  '纯棉': 536,
#  '惠顾': 537,
#  '再购': 538,
#  '套装': 539,
#  'gt': 540,
#  '完好': 541,
#  '透气': 542,
#  '拍下': 543,
#  '休闲': 544,
#  '个性': 545,
#  '补发': 546,
#  '亲们': 547,
#  '学校': 548,
#  '正在': 549,
#  '适合': 550,
#  '幸福': 551,
#  '礼物': 552,
#  '理解': 553,
#  '第一次': 554,
#  '2009': 555,
#  '保湿': 556,
#  '做工': 557,
#  '周期': 558,
#  '换成': 559,
#  '三天': 560,
#  '送上': 561,
#  '经常': 562,
#  '140': 563,
#  '拜托': 564,
#  '一张': 565,
#  '正好': 566,
#  '今天下午': 567,
#  '我爱你': 568,
#  '文字': 569,
#  '天天': 570,
#  '圆通': 571,
#  '品质': 572,
#  'QQ': 573,
#  '即可': 574,
#  '丑橘': 575,
#  '别人': 576,
#  '帽子': 577,
#  '耐用': 578,
#  '善良': 579,
#  '聪明': 580,
#  '谢谢合作': 581,
#  '安全': 582,
#  '买件': 583,
#  '一百个': 584,
#  '宣传': 585,
#  '厨房': 586,
#  '配件': 587,
#  '里面': 588,
#  '给力': 589,
#  '果子': 590,
#  '长安': 591,
#  '门卫': 592,
#  '076981669939': 593,
#  '20190318': 594,
#  '夏季': 595,
#  '提高': 596,
#  '销量': 597,
#  '棒棒': 598,
#  '首选': 599,
#  '以前': 600,
#  '加购': 601,
#  '功效': 602,
#  '真好': 603,
#  '18': 604,
#  '您好': 605,
#  '是否': 606,
#  '发大财': 607,
#  '东北': 608,
#  '好使': 609,
#  '处理': 610,
#  '顾客': 611,
#  '打错字': 612,
#  '旗舰店': 613,
#  '亲请': 614,
#  '再说': 615,
#  '爸爸': 616,
#  '用过': 617,
#  '小米': 618,
#  '五双': 619,
#  '热水器': 620,
#  '油烟机': 621,
#  '洗衣机': 622,
#  '使用寿命': 623,
#  '放在': 624,
#  '那种': 625,
#  '优先': 626,
#  '关顾': 627,
#  '注意': 628,
#  '大家': 629,
#  '超级': 630,
#  '正合适': 631,
#  '春季': 632,
#  '休闲鞋': 633,
#  '怎么样': 634,
#  '暖和': 635,
#  '登记': 636,
#  '云南': 637,
#  '面部': 638,
#  '万事如意': 639,
#  '贺卡': 640,
#  '超好': 641,
#  '充电器': 642,
#  '代餐': 643,
#  '打包': 644,
#  '货己': 645,
#  '每次': 646,
#  '家买': 647,
#  '物美价廉': 648,
#  '硅油': 649,
#  '减震': 650,
#  '手感': 651,
#  '百度': 652,
#  '坚持': 653,
#  'lt': 654,
#  '种子': 655,
#  '女孩': 656,
#  '不累': 657,
#  '女人': 658,
#  '快速': 659,
#  '两条': 660,
#  '能否': 661,
#  '永远': 662,
#  '尺码': 663,
#  '标准': 664,
#  '自己': 665,
#  '美女': 666,
#  '电脑': 667,
#  '三元': 668,
#  '经络': 669,
#  '简单': 670,
#  '咱们': 671,
#  '可能': 672,
#  '旗袍': 673,
#  '及时': 674,
#  '失望': 675,
#  '选购': 676,
#  '一生': 677,
#  '街道': 678,
#  '中药': 679,
#  '海藻': 680,
#  '方法': 681,
#  '别的': 682,
#  '亲刚': 683,
#  '迫不及待': 684,
#  '面料': 685,
#  '红河州': 686,
#  '订单': 687,
#  '减了': 688,
#  '亲给': 689,
#  '互相': 690,
#  '帮助': 691,
#  '实用': 692,
#  '很多': 693,
#  '提醒': 694,
#  '买一送一': 695,
#  '尺寸': 696,
#  '懒人': 697,
#  '丝巾': 698,
#  '领取': 699,
#  '到位': 700,
#  '货好': 701,
#  '售后': 702,
#  '苹果': 703,
#  '外套': 704,
#  '刚才': 705,
#  '两大瓶': 706,
#  '网址': 707,
#  '姐妹': 708,
#  '急用': 709,
#  '没事': 710,
#  '砍价': 711,
#  '免费': 712,
#  '选好': 713,
#  '3D': 714,
#  '注册': 715,
#  '查收': 716,
#  '两盒': 717,
#  '超爱': 718,
#  '如初': 719,
#  '公主': 720,
#  '一位': 721,
#  '人见人爱': 722,
#  '花见': 723,
#  '花开': 724,
#  '备受': 725,
#  '赞叹': 726,
#  '美少女': 727,
#  '钟晴': 728,
#  '纯中药': 729,
#  '黑头': 730,
#  '去屑': 731,
#  '40': 732,
#  '大大的': 733,
#  '邮箱': 734,
#  '勺子': 735,
#  '京东': 736,
#  '越做越': 737,
#  '一波': 738,
#  '找到': 739,
#  '新房': 740,
#  '放单': 741,
#  '到来': 742,
#  '退款': 743,
#  '欢迎': 744,
#  '七彩': 745,
#  '礼盒': 746,
#  '健身': 747,
#  '太棒了': 748,
#  '过程': 749,
#  '掉色': 750,
#  '起球': 751,
#  '物有所值': 752,
#  '买花': 753,
#  '相信': 754,
#  '内衣': 755,
#  '不是': 756,
#  '下雪': 757,
#  '核桃': 758,
#  '事情': 759,
#  '回头客': 760,
#  '容易': 761,
#  '橙子': 762,
#  '二十': 763,
#  '88': 764,
#  '红火': 765,
#  '生日礼物': 766,
#  '发件': 767,
#  '中奖': 768,
#  '开花': 769,
#  '把关': 770,
#  '买个': 771,
#  '电视': 772,
#  '马桶': 773,
#  '维修': 774,
#  '专业': 775,
#  '空调': 776,
#  '冰箱': 777,
#  '过后': 778,
#  '然后': 779,
#  '着急': 780,
#  '雨衣': 781,
#  '厚实': 782,
#  '小巧': 783,
#  '发给': 784,
#  '周日': 785,
#  '我发': 786,
#  '一年四季': 787,
#  '大哥': 788,
#  '精酿': 789,
#  '啤酒': 790,
#  '优质': 791,
#  '优惠价': 792,
#  '那就好': 793,
#  't95r': 794,
#  '已到': 795,
#  '店主': 796,
#  '潮流': 797,
#  '真是': 798,
#  '天气': 799,
#  '手套': 800,
#  '补偿': 801,
#  'CC': 802,
#  '粉色': 803,
#  '一家人': 804,
#  '这是': 805,
#  '完好无损': 806,
#  '姐姐': 807,
#  '不能': 808,
#  '挑选': 809,
#  '采购': 810,
#  '只有': 811,
#  '挑好': 812,
#  '女神': 813,
#  '同学': 814,
#  '中学': 815,
#  '享受': 816,
#  '好几个': 817,
#  '公分': 818,
#  '起到': 819,
#  '保护': 820,
#  '折叠': 821,
#  '课程': 822,
#  '不发': 823,
#  '礼包': 824,
#  '连衣裙': 825,
#  '轻柔': 826,
#  '师傅': 827,
#  '包包': 828,
#  '优惠活动': 829,
#  '告诉': 830,
#  '已买': 831,
#  '不锈钢': 832,
#  '一家': 833,
#  '好滴': 834,
#  '一盆': 835,
#  '小美女': 836,
#  '一块': 837,
#  '百世': 838,
#  '试吃': 839,
#  '...': 840,
#  '90': 841,
#  '犹豫': 842,
#  '升级': 843,
#  '更加': 844,
#  '怎样': 845,
#  '美容': 846,
#  '两件套': 847,
#  '不聊': 848,
#  '帅气': 849,
#  '毛孔': 850,
#  'ins': 851,
#  'OKK': 852,
#  '内裤': 853,
#  '好几家': 854,
#  '110': 855,
#  '多虑': 856,
#  '喝完': 857,
#  '省力': 858,
#  '需要的话': 859,
#  '春秋': 860,
#  '卡通': 861,
#  '红红火火': 862,
#  '三双': 863,
#  '排毒': 864,
#  '装在': 865,
#  '分钟': 866,
#  'bf': 867,
#  '人好': 868,
#  '一发': 869,
#  '抱歉': 870,
#  '没买错': 871,
#  '十斤': 872,
#  '再会': 873,
#  '娘家': 874,
#  '我查': 875,
#  '丽江市': 876,
#  '一岁': 877,
#  '一会儿': 878,
#  '情侣': 879,
#  '促进': 880,
#  '担心': 881,
#  '亲以': 882,
#  '试一试': 883,
#  '补肾': 884,
#  '120': 885,
#  '视频教程': 886,
#  '不贵': 887,
#  '我用': 888,
#  '认定': 889,
#  '照片': 890,
#  '第三次': 891,
#  '好运': 892,
#  '下面': 893,
#  '裙子': 894,
#  '拍照': 895,
#  '脸部': 896,
#  '30': 897,
#  '眼睛': 898,
#  '会常来': 899,
#  '发送': 900,
#  '紧绷': 901,
#  '橘子': 902,
#  '码数': 903,
#  '28': 904,
#  '料子': 905,
#  '贵州省': 906,
#  '贵阳市': 907,
#  '花溪区': 908,
#  '超市': 909,
#  '亲能': 910,
#  '没关系': 911,
#  '19': 912,
#  '一棵': 913,
#  '两袋': 914,
#  '白色': 915,
#  '十分': 916,
#  '过生日': 917,
#  'vip': 918,
#  '成活率': 919,
#  '外用': 920,
#  'nice': 921,
#  '平台': 922,
#  '信息': 923,
#  '干净': 924,
#  '爱车': 925,
#  '老客户': 926,
#  '直接': 927,
#  '兄弟': 928,
#  '喷雾': 929,
#  '搭配': 930,
#  '总是': 931,
#  '每年': 932,
#  '电池': 933,
#  '300': 934,
#  '五心': 935,
#  '戒指': 936,
#  '白皙': 937,
#  '品相': 938,
#  '买些': 939,
#  '配合': 940,
#  '好友': 941,
#  '巩固': 942,
#  '不少': 943,
#  '回复': 944,
#  '发芽': 945,
#  '买鞋': 946,
#  '哪种': 947,
#  '三张': 948,
#  '调理': 949,
#  '买到': 950,
#  '蒙自': 951,
#  '支架': 952,
#  '保质保量': 953,
#  '电动': 954,
#  '千玺': 955,
#  '进去': 956,
#  '那里': 957,
#  '蜂蜜': 958,
#  '加厚': 959,
#  '房子': 960,
#  '精选': 961,
#  '保驾护航': 962,
#  '好货': 963,
#  '大吉': 964,
#  'APP': 965,
#  '流畅': 966,
#  '充值': 967,
#  '时时': 968,
#  '分分': 969,
#  '11': 970,
#  '代理': 971,
#  '眼镜': 972,
#  '亲拍': 973,
#  'T1': 974,
#  '女友': 975,
#  '亲要': 976,
#  '温柔': 977,
#  '单独': 978,
#  '呵呵': 979,
#  '经济': 980,
#  '三种': 981,
#  '代购': 982,
#  '极好': 983,
#  '坐等': 984,
#  '恩恩': 985,
#  '严格': 986,
#  '两桶': 987,
#  '慧美纹': 988,
#  '点穴': 989,
#  '饮食': 990,
#  '慧美': 991,
#  '祛斑': 992,
#  '祛痘': 993,
#  '热线': 994,
#  '19825859936': 995,
#  '丝滑': 996,
#  '提升': 997,
#  '这家': 998,
#  '凳子': 999,
#  ...}

# %% [markdown]
# ### 转换文本

# %%
SENTENCE_LIMIT_SIZE =20

# %%
def dividesentence(a):
    sentence = []
    seg_list = jieba.cut(a, cut_all=True)
    for item in seg_list:
        sentence.append(item)
    return sentence

# %%
def convert_text_to_token(sentence, word_to_token_map=word_to_token, limit_size=SENTENCE_LIMIT_SIZE):
    """
    根据单词-编码映射表将单个句子转化为token
    
    @param sentence: 句子，str类型
    @param word_to_token_map: 单词到编码的映射
    @param limit_size: 句子最大长度。超过该长度的句子进行截断，不足的句子进行pad补全
    
    return: 句子转换为token后的列表
    """
    # 获取unknown单词和pad的token
    unk_id = word_to_token_map["<unk>"]
    pad_id = word_to_token_map["<pad>"]
    
    # 对句子进行token转换，对于未在词典中出现过的词用unk的token填充
    tokens = [word_to_token_map.get(word, unk_id) for word in dividesentence(sentence)]
    
    # Pad
    if len(tokens) < limit_size:
        tokens.extend([0] * (limit_size - len(tokens)))
    # Trunc
    else:
        tokens = tokens[:limit_size]
    
    return tokens

# %%
# 对x_train_pos文本处理
x_train_pos_tokens = []


for sentence in tqdm.tqdm(x_train_pos):
    tokens = convert_text_to_token(sentence)
    x_train_pos_tokens.append(tokens)
# Out:
# 100%|██████████| 6074/6074 [00:00<00:00, 30857.39it/s]

# %%
# 对x_train_neg文本处理
x_train_neg_tokens = []


for sentence in tqdm.tqdm(x_train_neg):
    tokens = convert_text_to_token(sentence)
    x_train_neg_tokens.append(tokens)
# Out:
# 100%|██████████| 5915/5915 [00:00<00:00, 20476.75it/s]

# %%
# 对x_test_pos文本处理
x_test_pos_tokens = []


for sentence in tqdm.tqdm(x_test_pos):
    tokens = convert_text_to_token(sentence)
    x_test_pos_tokens.append(tokens)
# Out:
# 100%|██████████| 955/955 [00:00<00:00, 19791.49it/s]

# %%
# 对x_test_neg文本处理
x_test_neg_tokens = []


for sentence in tqdm.tqdm(x_test_neg):
    tokens = convert_text_to_token(sentence)
    x_test_neg_tokens.append(tokens)
# Out:
# 100%|██████████| 1040/1040 [00:00<00:00, 20476.35it/s]

# %%
# 转化为numpy格式，方便处理
x_train_pos_tokens = np.array(x_train_pos_tokens)
x_train_neg_tokens = np.array(x_train_neg_tokens)
x_test_pos_tokens =np.array(x_test_pos_tokens)
x_test_neg_tokens =np.array(x_test_neg_tokens)

# %%
y_train_pos_targets = np.ones((x_train_pos_tokens.shape[0]))
y_test_pos_targets = np.ones((x_test_pos_tokens.shape[0]))
y_train_neg_targets = np.zeros((x_train_neg_tokens.shape[0]))
y_test_neg_targets = np.zeros((x_test_neg_tokens.shape[0]))

# %%
# 合并所有语料
x_train_tokens = np.concatenate((x_train_pos_tokens, x_train_neg_tokens), axis=0)
x_test_tokens = np.concatenate((x_test_pos_tokens, x_test_neg_tokens), axis=0)

# %%
# 合并所有target
y_train = np.concatenate((y_train_pos_targets,y_train_neg_targets), axis=0).reshape(-1, 1)
y_test = np.concatenate((y_test_pos_targets, y_test_neg_targets), axis=0).reshape(-1, 1)

# %%
print("The shape of all tokens in our corpus: ({}, {})".format(*x_train_tokens.shape))
# Out:
# The shape of all tokens in our corpus: (11989, 20)

# %%
print("The shape of all tokens in our corpus: ({}, {})".format(*x_test_tokens.shape))
# Out:
# The shape of all tokens in our corpus: (1995, 20)

# %%
print("The shape of all targets in our corpus: ({}, {})".format(*y_train.shape))
# Out:
# The shape of all targets in our corpus: (11989, 1)

# %%
print("The shape of all targets in our corpus: ({}, {})".format(*y_test.shape))
# Out:
# The shape of all targets in our corpus: (1995, 1)

# %% [markdown]
# ## 构造词向量
#
# 我们使用glove预训练好的词向量来做embedding:
#
# - 如果当前词没有对应词向量，则用随机数产生的向量替代
# - 如果当前词为< PAD >，则用0向量代替

# %% [markdown]
# ### 加载知乎预训练词向量

# %%
len(vocab)
# Out:
# 4116

# %%
with open("/Users/james/Downloads/sgns.zhihu.word", 'r') as f:
    words = set()
    word_to_vec = {}
    for line in f:
        line = line.strip().split()
        # 当前单词
        curr_word = line[0]
        words.add(curr_word)
        # 当前词向量
        word_to_vec[curr_word] = np.array(line[1:], dtype=np.float32)

# %%
print("The number of words which have pretrained-vectors in vocab is: {}".format(len(set(vocab)&set(words))))
print()
print("The number of words which do not have pretrained-vectors in vocab is : {}".format(len(set(vocab))-len(set(vocab)&set(words))))
# Out:
# The number of words which have pretrained-vectors in vocab is: 3006
#
# The number of words which do not have pretrained-vectors in vocab is : 1110

# %% [markdown]
# ### 构造词向量矩阵

# %%
VOCAB_SIZE = len(vocab)  # 4487
EMBEDDING_SIZE = 300

# %%
# 初始化词向量矩阵（这里命名为static是因为这个词向量矩阵用预训练好的填充，无需重新训练）
static_embeddings = np.zeros([VOCAB_SIZE, EMBEDDING_SIZE])

for word, token in tqdm.tqdm(word_to_token.items()):
    # 用glove词向量填充，如果没有对应的词向量，则用随机数填充
    word_vector = word_to_vec.get(word, 0.2 * np.random.random(EMBEDDING_SIZE) - 0.1)
    static_embeddings[token, :] = word_vector

# 重置PAD为0向量
pad_id = word_to_token["<pad>"]
static_embeddings[pad_id, :] = np.zeros(EMBEDDING_SIZE)
# Out:
# 100%|██████████| 4116/4116 [00:00<00:00, 39496.03it/s]

# %%
static_embeddings = static_embeddings.astype(np.float32)

# %%
static_embeddings.shape
# Out:
# (4116, 300)

# %% [markdown]
# ## 辅助函数

# %% [markdown]
# ### get_batch函数

# %%
def get_batch(x, y, batch_size=BATCH_SIZE, shuffle=True):
    assert x.shape[0] == y.shape[0], print("error shape!")
    # shuffle
    if shuffle:
        shuffled_index = np.random.permutation(range(x.shape[0]))

        x = x[shuffled_index]
        y = y[shuffled_index]
    
    # 统计共几个完整的batch
    n_batches = int(x.shape[0] / batch_size)
    
    for i in range(n_batches - 1):
        x_batch = x[i*batch_size: (i+1)*batch_size]
        y_batch = y[i*batch_size: (i+1)*batch_size]
    
        yield x_batch, y_batch

# %%
# 定义神经网络超参数
HIDDEN_SIZE = 512
LEARNING_RATE = 0.001
EPOCHES = 50
BATCH_SIZE = 256

# %%
with tf.name_scope("dnn"):
    # 输入及输出tensor
    with tf.name_scope("placeholders"):
        inputs = tf.placeholder(dtype=tf.int32, shape=(None, SENTENCE_LIMIT_SIZE), name="inputs")
        targets = tf.placeholder(dtype=tf.float32, shape=(None, 1), name="targets")
    
    # embeddings
    with tf.name_scope("embeddings"):
        # 用pre-trained词向量来作为embedding层
        embedding_matrix = tf.Variable(initial_value=static_embeddings, trainable=False, name="embedding_matrix")
        embed = tf.nn.embedding_lookup(embedding_matrix, inputs, name="embed")
        # 相加词向量得到句子向量
        sum_embed = tf.reduce_sum(embed, axis=1, name="sum_embed")
        
    # model
    with tf.name_scope("model"):
        # 隐层权重
        W1 = tf.Variable(tf.random_normal(shape=(EMBEDDING_SIZE, HIDDEN_SIZE), stddev=0.1), name="W1")
        b1 = tf.Variable(tf.zeros(shape=(HIDDEN_SIZE), name="b1"))
        
        # 输出层权重
        W2 = tf.Variable(tf.random_normal(shape=(HIDDEN_SIZE, 1), stddev=0.1), name="W2")
        b2 = tf.Variable(tf.zeros(shape=(1), name="b2"))
        
        # 结果
        z1 = tf.add(tf.matmul(sum_embed, W1), b1)
        a1 = tf.nn.relu(z1)
        
        logits = tf.add(tf.matmul(a1, W2), b2)
        outputs = tf.nn.sigmoid(logits, name="outputs")
    
    # loss
    with tf.name_scope("loss"):
        loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(labels=targets, logits=logits))
    
    # optimizer
    with tf.name_scope("optimizer"):
        optimizer = tf.train.AdamOptimizer(LEARNING_RATE).minimize(loss)
        
    # evaluation
    with tf.name_scope("evaluation"):
        correct_preds = tf.equal(tf.cast(tf.greater(outputs, 0.5), tf.float32), targets)
        accuracy = tf.reduce_sum(tf.reduce_sum(tf.cast(correct_preds, tf.float32), axis=1))

# %% [markdown]
# ## 训练模型

# %%
# 存储准确率
dnn_train_accuracy = []
dnn_test_accuracy = []

# %%
saver = tf.train.Saver()

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    writer = tf.summary.FileWriter("./graphs/dnn", tf.get_default_graph())
    
    n_batches = int(x_train.shape[0] / BATCH_SIZE)
    
    for epoch in range(EPOCHES):
        total_loss = 0
        
        for x_batch, y_batch in get_batch(x_train_tokens, y_train):
            _, batch_loss = sess.run([optimizer, loss],
                                     feed_dict={inputs: x_batch, targets: y_batch})
            
            total_loss += batch_loss
        
        # 在train上准确率
        train_corrects = sess.run(accuracy, feed_dict={inputs: x_train_tokens, targets: y_train})
        train_acc = train_corrects / x_train_tokens.shape[0]
        dnn_train_accuracy.append(train_acc)
        
        # 在test上准确率
        test_corrects = sess.run(accuracy, feed_dict={inputs: x_test_tokens, targets: y_test})
        test_acc = test_corrects / x_test_tokens.shape[0]
        dnn_test_accuracy.append(test_acc)
        
        print("Epoch: {}, Train loss: {:.4f}, Train accuracy: {:.4f}, Test accuracy: {:.4f}".format(epoch + 1, 
                                                                                                    total_loss/n_batches,
                                                                                                    train_acc,
                                                                                                    test_acc))
    # 存储模型
    saver.save(sess, "./checkpoints/dnn")
    writer.close()
# Out:
# Epoch: 1, Train loss: 0.2812, Train accuracy: 0.9263, Test accuracy: 0.9193
# Epoch: 2, Train loss: 0.1670, Train accuracy: 0.9373, Test accuracy: 0.9268
# Epoch: 3, Train loss: 0.1548, Train accuracy: 0.9289, Test accuracy: 0.9228
# Epoch: 4, Train loss: 0.1390, Train accuracy: 0.9481, Test accuracy: 0.9308
# Epoch: 5, Train loss: 0.1296, Train accuracy: 0.9533, Test accuracy: 0.9343
# Epoch: 6, Train loss: 0.1239, Train accuracy: 0.9576, Test accuracy: 0.9323
# Epoch: 7, Train loss: 0.1192, Train accuracy: 0.9580, Test accuracy: 0.9323
# Epoch: 8, Train loss: 0.1125, Train accuracy: 0.9621, Test accuracy: 0.9368
# Epoch: 9, Train loss: 0.1057, Train accuracy: 0.9640, Test accuracy: 0.9373
# Epoch: 10, Train loss: 0.0989, Train accuracy: 0.9645, Test accuracy: 0.9363
# Epoch: 11, Train loss: 0.0955, Train accuracy: 0.9629, Test accuracy: 0.9358
# Epoch: 12, Train loss: 0.0922, Train accuracy: 0.9681, Test accuracy: 0.9343
# Epoch: 13, Train loss: 0.0904, Train accuracy: 0.9690, Test accuracy: 0.9398
# Epoch: 14, Train loss: 0.0872, Train accuracy: 0.9709, Test accuracy: 0.9363
# Epoch: 15, Train loss: 0.0846, Train accuracy: 0.9701, Test accuracy: 0.9383
# Epoch: 16, Train loss: 0.0828, Train accuracy: 0.9697, Test accuracy: 0.9368
# Epoch: 17, Train loss: 0.0833, Train accuracy: 0.9721, Test accuracy: 0.9383
# Epoch: 18, Train loss: 0.0776, Train accuracy: 0.9739, Test accuracy: 0.9388
# Epoch: 19, Train loss: 0.0775, Train accuracy: 0.9713, Test accuracy: 0.9393
# Epoch: 20, Train loss: 0.0795, Train accuracy: 0.9736, Test accuracy: 0.9398
# Epoch: 21, Train loss: 0.0769, Train accuracy: 0.9735, Test accuracy: 0.9404
# Epoch: 22, Train loss: 0.0706, Train accuracy: 0.9751, Test accuracy: 0.9419
# Epoch: 23, Train loss: 0.0711, Train accuracy: 0.9746, Test accuracy: 0.9409
# Epoch: 24, Train loss: 0.0721, Train accuracy: 0.9743, Test accuracy: 0.9398
# Epoch: 25, Train loss: 0.0685, Train accuracy: 0.9760, Test accuracy: 0.9388
# Epoch: 26, Train loss: 0.0660, Train accuracy: 0.9739, Test accuracy: 0.9388
# Epoch: 27, Train loss: 0.0665, Train accuracy: 0.9753, Test accuracy: 0.9404
# Epoch: 28, Train loss: 0.0647, Train accuracy: 0.9756, Test accuracy: 0.9373
# Epoch: 29, Train loss: 0.0636, Train accuracy: 0.9766, Test accuracy: 0.9419
# Epoch: 30, Train loss: 0.0655, Train accuracy: 0.9764, Test accuracy: 0.9434
# Epoch: 31, Train loss: 0.0626, Train accuracy: 0.9746, Test accuracy: 0.9383
# Epoch: 32, Train loss: 0.0648, Train accuracy: 0.9765, Test accuracy: 0.9363
# Epoch: 33, Train loss: 0.0607, Train accuracy: 0.9784, Test accuracy: 0.9419
# Epoch: 34, Train loss: 0.0644, Train accuracy: 0.9770, Test accuracy: 0.9439
# Epoch: 35, Train loss: 0.0618, Train accuracy: 0.9770, Test accuracy: 0.9424
# Epoch: 36, Train loss: 0.0629, Train accuracy: 0.9781, Test accuracy: 0.9424
# Epoch: 37, Train loss: 0.0640, Train accuracy: 0.9782, Test accuracy: 0.9439
# Epoch: 38, Train loss: 0.0607, Train accuracy: 0.9787, Test accuracy: 0.9429
# Epoch: 39, Train loss: 0.0628, Train accuracy: 0.9763, Test accuracy: 0.9368
# Epoch: 40, Train loss: 0.0630, Train accuracy: 0.9749, Test accuracy: 0.9383
# Epoch: 41, Train loss: 0.0607, Train accuracy: 0.9780, Test accuracy: 0.9419
# Epoch: 42, Train loss: 0.0623, Train accuracy: 0.9788, Test accuracy: 0.9424
# Epoch: 43, Train loss: 0.0599, Train accuracy: 0.9759, Test accuracy: 0.9398
# Epoch: 44, Train loss: 0.0588, Train accuracy: 0.9777, Test accuracy: 0.9388
# Epoch: 45, Train loss: 0.0603, Train accuracy: 0.9791, Test accuracy: 0.9434
# Epoch: 46, Train loss: 0.0586, Train accuracy: 0.9793, Test accuracy: 0.9429
# Epoch: 47, Train loss: 0.0579, Train accuracy: 0.9794, Test accuracy: 0.9434
# Epoch: 48, Train loss: 0.0571, Train accuracy: 0.9794, Test accuracy: 0.9429
# Epoch: 49, Train loss: 0.0589, Train accuracy: 0.9774, Test accuracy: 0.9353
# Epoch: 50, Train loss: 0.0604, Train accuracy: 0.9783, Test accuracy: 0.9419

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(dnn_train_accuracy)
plt.plot(dnn_test_accuracy)
plt.ylim(ymin=0.5, ymax=1.01)
plt.title("The accuracy of DNN model")
plt.legend(["train", "test"])

# %%
# 在test上的准确率
with tf.Session() as sess:
    saver.restore(sess, "checkpoints/dnn")
    
    total_correct = 0
    acc = sess.run(accuracy,
                    feed_dict={inputs: x_test_tokens, 
                                targets: y_test})
    total_correct += acc
    print("The DNN model accuracy on test set: {:.2f}%".format(100* total_correct / x_test_tokens.shape[0]))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/dnn
# The DNN model accuracy on test set: 94.19%

# %% [markdown]
# # RNN模型

# %% [markdown]
# ## 构建模型图

# %%
# 清空图
tf.reset_default_graph()

# %%
# 定义网络超参数
HIDDEN_SIZE = 512
LEARNING_RATE = 0.001
KEEP_PROB = 0.5
EPOCHES = 50
BATCH_SIZE = 256

# %%
with tf.name_scope("rnn"):
    # placeholders
    with tf.name_scope("placeholders"):
        inputs = tf.placeholder(dtype=tf.int32, shape=(None, 20), name="inputs")
        targets = tf.placeholder(dtype=tf.float32, shape=(None, 1), name="targets")
    
    # embeddings
    with tf.name_scope("embeddings"):
        embedding_matrix = tf.Variable(initial_value=static_embeddings, trainable=False, name="embedding_matrix")
        embed = tf.nn.embedding_lookup(embedding_matrix, inputs, name="embed")
    
    # model
    with tf.name_scope("model"):
        # 构造lstm单元
        lstm = tf.contrib.rnn.LSTMCell(HIDDEN_SIZE, initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=123))
        # 添加dropout
        drop_lstm = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=KEEP_PROB)
        _, lstm_state = tf.nn.dynamic_rnn(drop_lstm, embed, dtype=tf.float32)
        
        # 输出层权重
        W = tf.Variable(tf.truncated_normal((HIDDEN_SIZE, 1), mean=0.0, stddev=0.1), name="W")
        b = tf.Variable(tf.zeros(1), name="b")
        
        logits = tf.add(tf.matmul(lstm_state.h, W), b)
        outputs = tf.nn.sigmoid(logits, name="outputs")
        
        loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(labels=targets, logits=logits))
    
    # optimizer
    with tf.name_scope("optimizer"):
        optimizer = tf.train.AdamOptimizer(LEARNING_RATE).minimize(loss)
    
    # evaluation
    with tf.name_scope("evaluation"):
        correct_preds = tf.equal(tf.cast(tf.greater(outputs, 0.5), tf.float32), targets)
        accuracy = tf.reduce_sum(tf.reduce_sum(tf.cast(correct_preds, tf.float32), axis=1))

# %% [markdown]
# ## 训练模型

# %%
# 存储准确率
rnn_train_accuracy = []
rnn_test_accuracy = []

# %%
saver = tf.train.Saver()

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    writer = tf.summary.FileWriter("./graphs/rnn", tf.get_default_graph())
    n_batches = int(x_train.shape[0] / BATCH_SIZE)
    
    for epoch in range(EPOCHES):
        total_loss = 0
        for x_batch, y_batch in get_batch(x_train_tokens, y_train):
            _, l = sess.run([optimizer, loss],
                            feed_dict={inputs: x_batch, 
                                       targets: y_batch})
            total_loss += l
        
        train_corrects = sess.run(accuracy, feed_dict={inputs: x_train_tokens, targets: y_train})
        train_acc = train_corrects / x_train_tokens.shape[0]
        rnn_train_accuracy.append(train_acc)

        test_corrects = sess.run(accuracy, feed_dict={inputs: x_test_tokens, targets: y_test})
        test_acc = test_corrects / x_test_tokens.shape[0]
        rnn_test_accuracy.append(test_acc)

        
        print("Training epoch: {}, Train loss: {:.4f}, Train accuracy: {:.4f}, Test accuracy: {:.4f}".format(epoch + 1, 
                                                                                                             total_loss / n_batches,
                                                                                                             train_acc,
                                                                                                             test_acc))
    
    saver.save(sess, "checkpoints/rnn")
    writer.close()
